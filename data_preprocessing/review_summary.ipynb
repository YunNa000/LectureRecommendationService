# %%
import sqlite3
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate, ChatPromptTemplate, load_prompt, FewShotChatMessagePromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler
from PRIVATE import OPENAI_API_KEY

from langchain.schema import BaseOutputParser
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.prompts.example_selector import LengthBasedExampleSelector
from langchain.prompts.example_selector.base import BaseExampleSelector
from langchain_core.prompts.few_shot import FewShotPromptTemplate, FewShotChatMessagePromptTemplate
from langchain_core.prompts.prompt import PromptTemplate

# %%
llm = ChatOpenAI(
    model = "gpt-4o-mini",
    temperature=0.1,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
conn = sqlite3.connect('./kwu-lecture-recommendation-v6.db')
cursor = conn.cursor()

cursor.execute('''
    ALTER TABLE LectureReview
    ADD COLUMN lecSummaryReview TEXT
''')
conn.commit()

# %%
cursor.execute('SELECT lecNumber, lecName FROM LectureReview')  # 왜 개수 제한 있는지
lectures = cursor.fetchall()

# %%
for lecture in lectures:
    if len(lecture) < 2:
        print("lecNum or lecClassName is null")
        continue

    lecNumber, lecClassName = lecture

    cursor.execute('''
        SELECT lecSummaryReview
        FROM LectureReview
        WHERE lecNumber = ?
    ''', (lecNumber,))
    existing_summary = cursor.fetchone()

    if existing_summary is None or existing_summary[0] is None:
        cursor.execute('''
            SELECT review 
            FROM LectureReview 
            WHERE lecNumber = ?
        ''', (lecNumber,))
        reviews = cursor.fetchall()

        if len(reviews) == 0:
            print(f"{lecNumber}'s review is null")
            continue

        formatted_reviews = []
        for i, review in enumerate(reviews[:5]):  # 상위 5개만 사용
            formatted_review = review[0].replace('\n', ' ')
            formatted_reviews.append(f"{i+1}. {formatted_review}")

        review_texts = "\n".join(formatted_reviews)

        lecture_info = {
            "lecNumber": lecNumber,
            "lecClassName": lecClassName,
            "lecReview": f"\n{review_texts}\n"
        }

        question = f"""
            아래는 {lecClassName} 강의에 대한 강의평이야. 강의평을 요약해.
            {review_texts}
        """

        example_prompt = FewShotChatMessagePromptTemplate(
            example_prompt=ChatPromptTemplate.from_messages(
                [
                    ("human", "{question}"),
                    ("ai", "{answer}"),
                ]
            ),
            examples=[
                {
                    "question": """
                        아래는 대학영어 강의에 대한 강의평이야. 강의평을 요약해.
                        1. 정말 좋은 교수님과 너무 고등학생 같은 시험.. 꼼꼼히 공부해야 합니다!
                        2. 설명 잘 해주시고 시험은 내신처럼 나옵니다. 꼼꼼히 지문 보세요.
                        3. 설명 잘해주시고 고등학교 영어 내신처럼 공부하면 됩니다
                        4. 교수님께서 설명을 친절하게 해주십니다. 2인1조로 구성되어 매수업 해야할 과제가 있지만 강의시간 안에 끝나서 부담이 없습니다. 정말 좋은 교수님이라 추천합니다
                        5. 기출문제 주십니다. 매 수업 팀 과제가 귀찮아요.  (2인 1조) 쁠은 다 채워주셔요.
                    """,
                    "answer": "시험은 고등학교 내신처럼 나오며 매 수업 팀 과제가 있지만 교수님이 매우 좋아요."
                },
                {
                    "question": """
                        아래는 광운인되기 강의에 대한 강의평이야. 강의평을 요약해.
                        1. 강의만 온라인으로 다 들으면 pass주는 과목입니다. 1학점 챙겨가세요
                        2. 온라인강의 꿀! 학기 말에 몰아서 하면 됩니다!!
                        3. 강의만 수강하시면 패스 충분히 받습니다. 온라인 강의라 부담이 없습니다
                        4. 강의 제때제때 틀어놓는 거랑 공지사항 내용 꼼꼼히 확인하기만 하면 쉽게 패스 가능합니다
                    """,
                    "answer": "공지사항을 제때 확인해야 하지만, 온라인 강의라 부담이 없어요."
                }
            ]
        )

        final_prompt = ChatPromptTemplate.from_messages(
            [
                ("system", "너는 강의를 선택하는 학생들을 위해 강의 리뷰를 한 줄로 요약하는 봇이야."),
                example_prompt,
                ("human", f"강의 리뷰 리스트들을 함축해서 최종적으로 한 줄의 답변만을 내놓아야 해. 리뷰에서 중복되거나 필수적이라고 생각되는 부분만을 한국어로 한 줄로 요약해. 요약 외에는 어떠한 답변도 더하지 마.\n{question}"),
            ]
        )

        chain = final_prompt | llm

        answer = chain.invoke({"question": question})

        final_answer = answer.content

        cursor.execute('''
            UPDATE LectureReview
            SET lecSummaryReview = ?
            WHERE lecNumber = ?
        ''', (final_answer, lecNumber))
        conn.commit()

        print(f"{lecNumber} {lecClassName} 요약: {final_answer}\n")

    else:
        print(f"{lecNumber} {lecClassName} 이미 요약이 존재합니다.\n")

conn.close()
# Out:
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-01 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 0000-1-8128-02 광운인되기 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-08 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-08 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-09 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-10 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-11 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-12 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-12 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-12 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-12 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-13 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-14 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-15 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-16 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 7000-1-3362-17 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# 고등학교 영어 내신과 비슷하며, 교재와 인터넷 과제를 잘 활용하면 쉽게 공부할 수 있습니다.6000-1-3362-05 대학영어 요약: 고등학교 영어 내신과 비슷하며, 교재와 인터넷 과제를 잘 활용하면 쉽게 공부할 수 있습니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 6000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 과제가 간단하고 시험이 통암기가 아니어서 성적을 잘 받을 수 있는 꿀강의입니다.F000-1-3362-01 대학영어 요약: 과제가 간단하고 시험이 통암기가 아니어서 성적을 잘 받을 수 있는 꿀강의입니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-02 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-03 대학영어 이미 요약이 존재합니다.
#
# 무난하고 부담 없이 들을 수 있으며, 시험 난이도가 낮고 교재 본문 위주로 진행됩니다.F000-1-3362-04 대학영어 요약: 무난하고 부담 없이 들을 수 있으며, 시험 난이도가 낮고 교재 본문 위주로 진행됩니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-04 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-05 대학영어 이미 요약이 존재합니다.
#
# 오경애 교수님의 수업은 친절하고 잘 가르치며, 과제와 시험 난이도가 낮아 성적을 잘 받을 수 있습니다.F000-1-3362-06 대학영어 요약: 오경애 교수님의 수업은 친절하고 잘 가르치며, 과제와 시험 난이도가 낮아 성적을 잘 받을 수 있습니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-06 대학영어 이미 요약이 존재합니다.
#
# 영어 회화와 작문에 비중을 두며, 매주 동영상 과제와 퀴즈가 있지만 적극적으로 참여할 자신이 있는 학생에게 추천합니다.F000-1-3362-07 대학영어 요약: 영어 회화와 작문에 비중을 두며, 매주 동영상 과제와 퀴즈가 있지만 적극적으로 참여할 자신이 있는 학생에게 추천합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# F000-1-3362-07 대학영어 이미 요약이 존재합니다.
#
# 교수의 강의력은 떨어지지만 조별 활동과 시험 난이도가 낮아 성적 받기 쉬운 수업입니다.0000-1-3362-01 대학영어 요약: 교수의 강의력은 떨어지지만 조별 활동과 시험 난이도가 낮아 성적 받기 쉬운 수업입니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 0000-1-3362-01 대학영어 이미 요약이 존재합니다.
#
# 주 첫 시간에 이론, 두 번째 시간에 실습을 하며, 기말은 7천 자의 글쓰기 최종과제로 대체되고, 과제는 소감문 다섯 편 제출입니다.I000-1-3095-01 융합적사고와글쓰기 요약: 주 첫 시간에 이론, 두 번째 시간에 실습을 하며, 기말은 7천 자의 글쓰기 최종과제로 대체되고, 과제는 소감문 다섯 편 제출입니다.
#
# 교수님이 친절하게 글쓰기 방법을 알려주며, 과제가 많지 않아 부담 없이 수업을 들을 수 있습니다.I000-1-3095-02 융합적사고와글쓰기 요약: 교수님이 친절하게 글쓰기 방법을 알려주며, 과제가 많지 않아 부담 없이 수업을 들을 수 있습니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 친절하고 재미있지만, 매 수업 논의 후 책 페이지를 찢어내는 방식이 귀찮고 중간고사 문제는 약간 변형되어 출제됩니다.I000-1-3095-03 융합적사고와글쓰기 요약: 교수님이 친절하고 재미있지만, 매 수업 논의 후 책 페이지를 찢어내는 방식이 귀찮고 중간고사 문제는 약간 변형되어 출제됩니다.
#
# I000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 친절하고 따뜻하시며, 노력하면 좋은 결과를 얻을 수 있지만 과제가 많지 않고 수업이 지루할 수 있습니다.I000-1-3095-04 융합적사고와글쓰기 요약: 교수님이 친절하고 따뜻하시며, 노력하면 좋은 결과를 얻을 수 있지만 과제가 많지 않고 수업이 지루할 수 있습니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 과제가 많고 성적이 까다로워서 부담이 크며, 교수의 설명이 부족합니다.I000-1-3095-05 융합적사고와글쓰기 요약: 과제가 많고 성적이 까다로워서 부담이 크며, 교수의 설명이 부족합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 시험이 없고 글쓰기 과제를 여러 번에 걸쳐 완성하면 되며, 교수님이 매우 친절하고 성적도 잘 주십니다.I000-1-3095-06 융합적사고와글쓰기 요약: 시험이 없고 글쓰기 과제를 여러 번에 걸쳐 완성하면 되며, 교수님이 매우 친절하고 성적도 잘 주십니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 수업은 재미있고 교수님에게 질문하면 잘 답변하지만, 출결과 과제가 엄격하고 교수님이 소통에 소홀합니다.I000-1-3095-07 융합적사고와글쓰기 요약: 수업은 재미있고 교수님에게 질문하면 잘 답변하지만, 출결과 과제가 엄격하고 교수님이 소통에 소홀합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 시험이 없고 글쓰기 과제로 평가받으며, 교수님이 첨삭과 피드백을 잘 해주셔서 부담이 적습니다.I000-1-3095-08 융합적사고와글쓰기 요약: 시험이 없고 글쓰기 과제로 평가받으며, 교수님이 첨삭과 피드백을 잘 해주셔서 부담이 적습니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 학생 글에 대해 공개 피드백을 요구하며, 뒷자리에 앉으면 성적에 불이익이 있으니 주의해야 합니다.I000-1-3095-09 융합적사고와글쓰기 요약: 교수님이 학생 글에 대해 공개 피드백을 요구하며, 뒷자리에 앉으면 성적에 불이익이 있으니 주의해야 합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-09 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 과제가 적당히 주어지고 교수님이 학생 참여를 유도하지만, 개인적으로 수업에 대한 불만이 있는 학생도 있습니다.I000-1-3095-11 융합적사고와글쓰기 요약: 과제가 적당히 주어지고 교수님이 학생 참여를 유도하지만, 개인적으로 수업에 대한 불만이 있는 학생도 있습니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-11 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 정성껏 강의하시고, 개인 레포트와 피드백을 통해 유익한 수업을 제공하므로 꼭 추천합니다.I000-1-3095-12 융합적사고와글쓰기 요약: 교수님이 정성껏 강의하시고, 개인 레포트와 피드백을 통해 유익한 수업을 제공하므로 꼭 추천합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-12 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 글쓰기 수업이지만 교수님의 주관적인 이야기와 사담이 많아 학점이 아깝고, 성적 기준이 불명확합니다.I000-1-3095-13 융합적사고와글쓰기 요약: 글쓰기 수업이지만 교수님의 주관적인 이야기와 사담이 많아 학점이 아깝고, 성적 기준이 불명확합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-13 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 과제가 많고 고학년에게는 힘들 수 있지만, 교수님이 친절하고 열정적이며 A+를 받을 기회가 많습니다.I000-1-3095-14 융합적사고와글쓰기 요약: 과제가 많고 고학년에게는 힘들 수 있지만, 교수님이 친절하고 열정적이며 A+를 받을 기회가 많습니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# I000-1-3095-14 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님은 열정적이지만 성적이 깐깐하고 과제가 많아 글쓰기 실력이 부족한 학생에게는 추천하지 않습니다.1000-1-3095-01 융합적사고와글쓰기 요약: 교수님은 열정적이지만 성적이 깐깐하고 과제가 많아 글쓰기 실력이 부족한 학생에게는 추천하지 않습니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님의 수업 진행이 두서 없고 귀찮은 과제가 많아 글쓰기 실력 향상에 의문이 듭니다.1000-1-3095-02 융합적사고와글쓰기 요약: 교수님의 수업 진행이 두서 없고 귀찮은 과제가 많아 글쓰기 실력 향상에 의문이 듭니다.
#
# 1000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 재미있고 부담 없는 인문교양 수업으로, 과제와 시험이 적고 교수님이 배려해주십니다.1000-1-3095-03 융합적사고와글쓰기 요약: 재미있고 부담 없는 인문교양 수업으로, 과제와 시험이 적고 교수님이 배려해주십니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 학생을 위하고 시험이 매우 쉬워 출석만 잘하면 좋은 성적을 받을 수 있습니다.1000-1-3095-05 융합적사고와글쓰기 요약: 교수님이 학생을 위하고 시험이 매우 쉬워 출석만 잘하면 좋은 성적을 받을 수 있습니다.
#
# 1000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 친절하고 중간고사는 과제로 대체되며, 수업을 잘 따라가면 성적이 잘 나옵니다.1000-1-3095-06 융합적사고와글쓰기 요약: 교수님이 친절하고 중간고사는 과제로 대체되며, 수업을 잘 따라가면 성적이 잘 나옵니다.
#
# 1000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 1000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 친절하고 흥미로운 수업이며, 글쓰기 과제가 있지만 부담 없이 학점을 받을 수 있습니다.3000-1-3095-01 융합적사고와글쓰기 요약: 교수님이 친절하고 흥미로운 수업이며, 글쓰기 과제가 있지만 부담 없이 학점을 받을 수 있습니다.
#
# 3000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 매우 친절하고 강의력이 뛰어나며, 과제 피드백과 출석에 너그러운 편이라 추천할 만한 강의입니다.3000-1-3095-02 융합적사고와글쓰기 요약: 교수님이 매우 친절하고 강의력이 뛰어나며, 과제 피드백과 출석에 너그러운 편이라 추천할 만한 강의입니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 깔끔하게 수업을 진행하시고, 과제는 논문 작성 하나로 기한이 길어 편하며, 시험은 어렵지 않습니다.3000-1-3095-03 융합적사고와글쓰기 요약: 교수님이 깔끔하게 수업을 진행하시고, 과제는 논문 작성 하나로 기한이 길어 편하며, 시험은 어렵지 않습니다.
#
# 3000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-03 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님의 열의가 대단하고, 시험보다 보고서가 중요하며 과제가 많아 부담이 될 수 있습니다.3000-1-3095-04 융합적사고와글쓰기 요약: 교수님의 열의가 대단하고, 시험보다 보고서가 중요하며 과제가 많아 부담이 될 수 있습니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 과제가 많고 수업이 비효율적이지만 교수님의 피드백은 좋습니다.3000-1-3095-05 융합적사고와글쓰기 요약: 과제가 많고 수업이 비효율적이지만 교수님의 피드백은 좋습니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 학생들을 배려하며 수업을 재밌게 진행하지만, 피피티 자료가 간단해 집중이 필요합니다.3000-1-3095-06 융합적사고와글쓰기 요약: 교수님이 학생들을 배려하며 수업을 재밌게 진행하지만, 피피티 자료가 간단해 집중이 필요합니다.
#
# 3000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 친절하고 따뜻하지만, 수업이 지루하고 글쓰기 과제가 까다롭습니다.3000-1-3095-07 융합적사고와글쓰기 요약: 교수님이 친절하고 따뜻하지만, 수업이 지루하고 글쓰기 과제가 까다롭습니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-07 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 시험 문제를 미리 알려주고 출결과 과제가 적어 쉽게 수업을 들을 수 있지만, 교수님에 대한 호불호가 갈립니다.3000-1-3095-08 융합적사고와글쓰기 요약: 시험 문제를 미리 알려주고 출결과 과제가 적어 쉽게 수업을 들을 수 있지만, 교수님에 대한 호불호가 갈립니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 3000-1-3095-08 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 과제가 매우 많고 채점 기준이 불명확하며 교수님의 수업 내용이 혼란스러워 추천하지 않습니다.5000-1-3095-01 융합적사고와글쓰기 요약: 과제가 매우 많고 채점 기준이 불명확하며 교수님의 수업 내용이 혼란스러워 추천하지 않습니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-01 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 시험 범위는 불확실하지만 부담 없이 조별토론과 과제를 수행하면 성적이 잘 나오는 무난한 수업입니다.5000-1-3095-02 융합적사고와글쓰기 요약: 시험 범위는 불확실하지만 부담 없이 조별토론과 과제를 수행하면 성적이 잘 나오는 무난한 수업입니다.
#
# 5000-1-3095-02 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 매우 착하시고, 수업이 재미있으며, 시험과 과제가 쉬워 좋은 점수를 받을 수 있습니다.5000-1-3095-03 융합적사고와글쓰기 요약: 교수님이 매우 착하시고, 수업이 재미있으며, 시험과 과제가 쉬워 좋은 점수를 받을 수 있습니다.
#
# 휴강이 잦고 과제가 많지 않지만, 강의 내용이 글쓰기와 관련이 적고 피드백이 부족해 실질적인 배움이 적습니다.5000-1-3095-04 융합적사고와글쓰기 요약: 휴강이 잦고 과제가 많지 않지만, 강의 내용이 글쓰기와 관련이 적고 피드백이 부족해 실질적인 배움이 적습니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-04 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 시험은 고등학교 수준이고 과제는 많지 않지만 피드백이 잘 이루어지며, 수업이 지루할 수 있지만 A+ 받기 쉬운 과목입니다.5000-1-3095-05 융합적사고와글쓰기 요약: 시험은 고등학교 수준이고 과제는 많지 않지만 피드백이 잘 이루어지며, 수업이 지루할 수 있지만 A+ 받기 쉬운 과목입니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-05 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 교수님이 매우 좋고, 글쓰기 기본기를 체계적으로 가르치며, 과제와 시험이 부담 없이 진행됩니다.5000-1-3095-06 융합적사고와글쓰기 요약: 교수님이 매우 좋고, 글쓰기 기본기를 체계적으로 가르치며, 과제와 시험이 부담 없이 진행됩니다.
#
# 5000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# 5000-1-3095-06 융합적사고와글쓰기 이미 요약이 존재합니다.
#
# ...
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 5100-2-0613-02 미시경제학 이미 요약이 존재합니다.
#
# 수업 내용이 부족하고 어려워 독학이 필수이며, 교수님의 설명이 부족하다는 의견이 많습니다.7420-3-2004-01 신호및시스템 요약: 수업 내용이 부족하고 어려워 독학이 필수이며, 교수님의 설명이 부족하다는 의견이 많습니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 7420-3-2004-01 신호및시스템 이미 요약이 존재합니다.
#
# 교수님의 강의력이 좋고, 매일 복습하면 좋은 점수를 받을 수 있지만, 내용이 어려워 벼락치기는 비추천입니다.5080-3-5306-01 중급회계1 요약: 교수님의 강의력이 좋고, 매일 복습하면 좋은 점수를 받을 수 있지만, 내용이 어려워 벼락치기는 비추천입니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 5080-3-5306-01 중급회계1 이미 요약이 존재합니다.
#
# 교수님은 친절하지만 과제가 많고 시험 범위가 넓어 부담스럽습니다.5080-3-8560-01 노사관계 요약: 교수님은 친절하지만 과제가 많고 시험 범위가 넓어 부담스럽습니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 5080-3-8560-01 노사관계 이미 요약이 존재합니다.
#
# 팀 프로젝트와 설계가 힘들지만 이론 이해는 잘 되며, 족보가 필요합니다.7320-3-4023-01 전기공학머신러닝실습 요약: 팀 프로젝트와 설계가 힘들지만 이론 이해는 잘 되며, 족보가 필요합니다.
#
# 7320-3-4023-01 전기공학머신러닝실습 이미 요약이 존재합니다.
#
# 7320-3-4023-01 전기공학머신러닝실습 이미 요약이 존재합니다.
#
# 형법총론2는 상위권 경쟁이 치열하고, 교수님이 명확하게 설명하지만 복습이 필수이며 기말이 더 어렵습니다.F030-2-4220-02 형법총론2 요약: 형법총론2는 상위권 경쟁이 치열하고, 교수님이 명확하게 설명하지만 복습이 필수이며 기말이 더 어렵습니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# F030-2-4220-02 형법총론2 이미 요약이 존재합니다.
#
# 교수님은 강의력이 뛰어나고 학점은 잘 주지만, 팀플이 어렵고 잔소리가 많습니다.5100-2-0048-01 거시경제학 요약: 교수님은 강의력이 뛰어나고 학점은 잘 주지만, 팀플이 어렵고 잔소리가 많습니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 5100-2-0048-01 거시경제학 이미 요약이 존재합니다.
#
# 강의 내용이 어렵지만 교수님이 강조한 부분 위주로 공부하면 성적을 잘 받을 수 있습니다.F030-3-8544-01 부동산공법 요약: 강의 내용이 어렵지만 교수님이 강조한 부분 위주로 공부하면 성적을 잘 받을 수 있습니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# F030-3-8544-01 부동산공법 이미 요약이 존재합니다.
#
# 시험이 쉬워서 성적 변별력이 없지만, 교수님 수업은 부담이 적고 편하게 진행됩니다.5080-3-1149-01 유통관리 요약: 시험이 쉬워서 성적 변별력이 없지만, 교수님 수업은 부담이 적고 편하게 진행됩니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 교수님의 설명은 좋지만 수업 분위기가 불편하고, 족보를 활용해야 성적이 잘 나올 수 있는 강의입니다.7070-4-0629-01 반도체공학 요약: 교수님의 설명은 좋지만 수업 분위기가 불편하고, 족보를 활용해야 성적이 잘 나올 수 있는 강의입니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 7070-4-0629-01 반도체공학 이미 요약이 존재합니다.
#
# 1학점 쉽게 받을 수 있는 강의입니다.1270-2-1234-01 진로탐색및설계 요약: 1학점 쉽게 받을 수 있는 강의입니다.
#
# 내용은 이해할 수 있지만 성적이 걱정됩니다.5100-1-4449-02 국제통상학개론 요약: 내용은 이해할 수 있지만 성적이 걱정됩니다.
#
# PPT 양이 많지만 내용이 쉬워서 잘 정리하면 시험에서 좋은 성적을 받을 수 있습니다.F000-1-4432-03 인공지능과컴퓨팅사고 요약: PPT 양이 많지만 내용이 쉬워서 잘 정리하면 시험에서 좋은 성적을 받을 수 있습니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# F000-1-4432-03 인공지능과컴퓨팅사고 이미 요약이 존재합니다.
#
# 교수님은 친절하지만, 기초적인 내용만 가르치고 수업 체계가 부족해 실무에 도움이 되지 않습니다.3230-2-7702-02 컴퓨터그래픽디자인 요약: 교수님은 친절하지만, 기초적인 내용만 가르치고 수업 체계가 부족해 실무에 도움이 되지 않습니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-7702-02 컴퓨터그래픽디자인 이미 요약이 존재합니다.
#
# 이윤미 교수님의 유기금속화학 강의는 알찬 내용과 친절한 설명으로 학점이 잘 나옵니다.6050-4-7377-01 유기금속화학 요약: 이윤미 교수님의 유기금속화학 강의는 알찬 내용과 친절한 설명으로 학점이 잘 나옵니다.
#
# 6050-4-7377-01 유기금속화학 이미 요약이 존재합니다.
#
# 6050-4-7377-01 유기금속화학 이미 요약이 존재합니다.
#
# 6050-4-7377-01 유기금속화학 이미 요약이 존재합니다.
#
# 6050-4-7377-01 유기금속화학 이미 요약이 존재합니다.
#
# 강의는 온라인으로 수강 가능하지만, 매주 과제가 있고 시험은 수업 후 진행되어 부담이 클 수 있습니다.5080-4-8564-01 사업과금융 요약: 강의는 온라인으로 수강 가능하지만, 매주 과제가 있고 시험은 수업 후 진행되어 부담이 클 수 있습니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 5080-4-8564-01 사업과금융 이미 요약이 존재합니다.
#
# 교수님의 강의력이 좋고, 열심히 하면 성적이 잘 나오며 수업이 즐겁습니다.F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 요약: 교수님의 강의력이 좋고, 열심히 하면 성적이 잘 나오며 수업이 즐겁습니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# F030-2-1840-01 테스트용-10년-2학기-원-행정법총론-24-1학기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-1-8085-01 논리적으로사고하기 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 0000-2-3796-01 기초그래픽디자인 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 3230-2-9694-01 미래시나리오전략기획 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-01 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5080-3-1149-02 유통관리 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 5100-4-3773-01 캡스톤설계국제통상실습 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7060-2-1411-03 전자기학1 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# 7420-3-1721-01 통신이론 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.
#
# I040-3-9151-01 기계학습 이미 요약이 존재합니다.

# %% [markdown]
# 0----------------------------------------

# %%
example_answer = [
{
"question": """
아래는 대학영어 강의에 대한 강의평이야. 강의평을 요약해.
1. 정말 좋은 교수님과 너무 고등학생 같은 시험.. 꼼꼼히 공부해야 합니다!
2. 설명 잘 해주시고 시험은 내신처럼 나옵니다. 꼼꼼히 지문 보세요.
3. 설명 잘해주시고 고등학교 영어 내신처럼 공부하면 됩니다
4. 교수님께서 설명을 친절하게 해주십니다. 2인1조로 구성되어 매수업 해야할 과제가 있지만 강의시간 안에 끝나서 부담이 없습니다. 정말 좋은 교수님이라 추천합니다
5. 기출문제 주십니다. 매 수업 팀 과제가 귀찮아요.  (2인 1조) 쁠은 다 채워주셔요.
""",
"answer": """
시험은 고등학교 내신처럼 나오며 매 수업 팀 과제가 있지만 교수님이 매우 좋아요.
""",
},
{
"question": """
아래는 광운인되기 강의에 대한 강의평이야. 강의평을 요약해.
1. 강의만 온라인으로 다 들으면 pass주는 과목입니다. 1학점 챙겨가세요
2. 온라인강의 꿀! 학기 말에 몰아서 하면 됩니다!!
3. 강의만 수강하시면 패스 충분히 받습니다. 온라인 강의라 부담이 없습니다
4. 강의 제때제때 틀어놓는 거랑 공지사항 내용 꼼꼼히 확인하기만 하면 쉽게 패스 가능합니다
""",
"answer": """
공지사항을 제때 확인해야 하지만, 온라인 강의라 부담이 없어요.
""",
},
{
"question": """
아래는 유기화학1 강의에 대한 강의평이야. 강의평을 요약해.
1. 교수님 강의력 좋은 편은 아님.. 족보 타는 강의 기말은 많이는 안탄듯 가지고 있으면 좋음
2. 족보 너무 많이 탑니다 ㅠ 족보 무조건 구해서 시험 보시는 거 추천드립니다
3. 과제, 족보 이 두개만 풀면 시험 무난하게 볼 수 있어요. 근데 성적을 잘 주시는 편은 아닌 것 같습니다
""",
"answer": """
교수님의 강의력이 좋은 편이 아니고, 과제와 족보가 중요하며 성적을 잘 주시는 편이 아니예요.
""",
},
]

# %%
import sqlite3

conn = sqlite3.connect('../database/lecture.db')
cursor = conn.cursor()

cursor.execute('SELECT lecNumber, lecClassName FROM LectureTable')
lectures = cursor.fetchall()

for lecture in lectures:
    if len(lecture) < 2:
        print("lecNum or lecClassName is null")
        continue
    
    lecNumber, lecClassName = lecture

    cursor.execute('''
        SELECT lecReview 
        FROM LecReviewTable 
        WHERE lecNumber = ?
    ''', (lecNumber,))
    
    reviews = cursor.fetchall()
    
    if len(reviews) == 0:
        print(f"{lecNumber}'s review is null")
        continue
    
    formatted_reviews = []
    for i, review in enumerate(reviews[:5]): # 상위 5개만
        formatted_review = review[0].replace('\n', ' ')
        formatted_reviews.append(f"{i+1}. {formatted_review}")
    
    review_texts = "\n".join(formatted_reviews)
    
    lecture_info = {
        "lecNumber": lecNumber,
        "lecClassName": lecClassName,
        "lecReview": f"\n{review_texts}\n"
    }
    
    question = f"""
아래는 {lecClassName} 강의에 대한 강의평이야. 강의평을 요약해.
{review_texts}
    """
    
    example_prompt = ChatPromptTemplate.from_messages(
        [
            ("human", "{question}"),
            ("ai", "{answer}"),
        ]
    )

    example_prompt = FewShotChatMessagePromptTemplate(
        example_prompt=example_prompt,
        examples=example_answer,
    )

    final_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "너는 강의를 선택하는 학생들을 위해 강의 리뷰를 한 줄로 요약하는 봇이야."),
            example_prompt,
            ("human", "강의 리뷰 리스트들을 함축해서 최종적으로 한 줄의 답변만을 내놓아야 해. 리뷰에서 중복되거나 필수적이라고 생각되는 부분만을 한국어로 한 줄로 요약해. 요약 외에는 어떠한 답변도 더하지 마.\n"+question),
        ]
    )

    chain = final_prompt | llm

    answer = chain.invoke({"question": question})

    final_answer = answer.content

    cursor.execute('''
        UPDATE LectureTable
        SET lecSummaryReview = ?
        WHERE lecNumber = ?
    ''', (final_answer, lecNumber))
    conn.commit()
    
    # print(f"\n{lecNumber} {lecClassName} answer: {final_answer}")
    print()

conn.close()
