# %%
import pandas as pd
import sqlite3

csv_data = pd.read_csv('level_4_손원택수정1_중복제거.csv', encoding="EUC-KR")
conn = sqlite3.connect('lecture-3-final-test.db')

query = "SELECT lecNumber FROM LectureTable"
db_data = pd.read_sql_query(query, conn)

conn.close()

csv_lec_numbers = set(csv_data['학정번호'])
db_lec_numbers = set(db_data['lecNumber'])

unique_lec_numbers = csv_lec_numbers - db_lec_numbers

print("csv에만 존재하는 학정번호")
print(unique_lec_numbers)
# Out:
# csv에만 존재하는 학정번호
# ...

# %%
df = pd.read_csv("./level_4_손원택수정1_중복제거.csv", encoding="CP949")

lecNumLists = df['학정번호'].tolist()

print(lecNumLists)
print(lecNumLists.__len__())
# Out:
# ['0000-1-8128-01', '0000-1-8128-02', '7000-1-3362-01', '7000-1-3362-02', '7000-1-3362-03', '7000-1-3362-04', '7000-1-3362-05', '7000-1-3362-06', '7000-1-3362-07', '7000-1-3362-08', '7000-1-3362-09', '7000-1-3362-10', '7000-1-3362-11', '7000-1-3362-12', '7000-1-3362-13', '7000-1-3362-14', '7000-1-3362-15', '7000-1-3362-16', '7000-1-3362-17', '6000-1-3362-01', '6000-1-3362-02', '6000-1-3362-03', '6000-1-3362-04', '6000-1-3362-05', '6000-1-3362-06', 'F000-1-3362-01', 'F000-1-3362-02', 'F000-1-3362-03', 'F000-1-3362-04', 'F000-1-3362-05', 'F000-1-3362-06', 'F000-1-3362-07', '0000-1-3362-01', 'I000-1-3095-01', 'I000-1-3095-02', 'I000-1-3095-03', 'I000-1-3095-04', 'I000-1-3095-05', 'I000-1-3095-06', 'I000-1-3095-07', 'I000-1-3095-08', 'I000-1-3095-09', 'I000-1-3095-10', 'I000-1-3095-11', 'I000-1-3095-12', 'I000-1-3095-13', 'I000-1-3095-14', '1000-1-3095-01', '1000-1-3095-02', '1000-1-3095-03', '1000-1-3095-04', '1000-1-3095-05', '1000-1-3095-06', '3000-1-3095-01', '3000-1-3095-02', '3000-1
# ...
