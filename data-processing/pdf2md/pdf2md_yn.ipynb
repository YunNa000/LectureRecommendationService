# %%
import PyPDF2

def extract_pages(input_pdf_path, output_pdf_path, start_page, end_page):
    with open(input_pdf_path, 'rb') as input_file:
        reader = PyPDF2.PdfReader(input_file)
        writer = PyPDF2.PdfWriter()
        output_pdf_path = "./pdfs/"+output_pdf_path

        for page_num in range(start_page-1, end_page):
            page = reader.pages[page_num]
            writer.add_page(page)

        with open(output_pdf_path, 'wb') as output_file:
            writer.write(output_file)

    print(f'{output_pdf_path} done')

# 1. 수강신청 관련 내용
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '수강신청_관련.pdf', 8, 18)  # 수강신청.pdf

# 2. 졸업요건 관련 내용
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '졸업요건_관련(일반/편입생, 공학인증제, 다전공).pdf', 26, 31)  # 졸업요건_일반,편입생 (19년 이후 신입학자).pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '졸업요건_관련(일반/편입생, 공학인증제, 다전공).pdf', 44, 46)  # 졸업요건_공학인증제 (19년 이후 신입학자).pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '졸업요건_관련(일반/편입생, 공학인증제, 다전공).pdf', 37, 39)  # 졸업요건_다전공 (19년 이후 신입학자).pdf

# 3. 기타 학사정보 관련 내용
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 19, 19)  # 교과이수구분 및 학정번호.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 32, 33)  # 교양 필수 교과목 수강 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 42, 43)  # 공학교육인증제1.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 48, 78)  # 공학교육인증제2.pdf (좀 넓게 잡음 입학년도)
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 34, 35)  # 다전공 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 83, 86)  # 다학년 다학기 프로젝트 (KW-VIP) 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 91, 91)  # 현장실습학기제 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 87, 88)  # 참빛설계학기 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 81, 82)  # 서비스러닝 교과목 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 90, 90)  # 매치업 집중이수제 교내 강좌 수강 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 89, 89)  # K-MOOC 교내 온라인강좌 수강 안내.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 34, 34)  # 편입생이 이수해야 할 교과목 및 학점.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 92, 95)  # 특별교육과정 (CDP, R.O.T.C., 글로벌인재트랙인증제).pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 79, 80)  # 학-석사 연계과정.pdf
extract_pages('2-1. 수강신청_자료집_전체(2024-2).pdf', '기타_학사정보.pdf', 40, 41)  # 연계전공 안내.pdf
# Out:
# ./pdfs/수강신청.pdf done
# ./pdfs/졸업이수학점 안내 (19년 이후 신입학자).pdf done
# ./pdfs/교양 필수 교과목 수강 안내.pdf done
# ./pdfs/편입생이 이수해야 할 교과목 및 학점.pdf done
# ./pdfs/다전공 안내.pdf done
# ./pdfs/연계전공 안내.pdf done
# ./pdfs/공학교육인증제.pdf done
# ./pdfs/학-석사 연계과정.pdf done
# ./pdfs/서비스러닝 교과목 안내.pdf done
# ./pdfs/다학년 다학기 프로젝트 (KW-VIP) 안내.pdf done
# ./pdfs/참빛설계학기 안내.pdf done
# ./pdfs/K-MOOC 교내 온라인강좌 수강 안내.pdf done
# ./pdfs/매치업 집중이수제 교내 강좌 수강 안내.pdf done
# ./pdfs/현장실습학기제 안내.pdf done
# ./pdfs/특별교육과정 (CDP, R.O.T.C., 글로벌인재트랙인증제).pdf done

# %%
import os
from pdf2image import convert_from_path
from PIL import Image


pdf_dir = './pdfs'
img_dir = './imgs'


os.makedirs(img_dir, exist_ok=True)


for filename in os.listdir(pdf_dir):
    if filename.endswith('.pdf'):
        pdf_path = os.path.join(pdf_dir, filename)

        images = convert_from_path(pdf_path)

        total_width = max(image.width for image in images)
        total_height = sum(image.height for image in images)

        combined_image = Image.new('RGB', (total_width, total_height))

        y_offset = 0
        for image in images:
            combined_image.paste(image, (0, y_offset))
            y_offset += image.height

        img_path = os.path.join(
            img_dir, f"{os.path.splitext(filename)[0]}.jpg")
        combined_image.save(img_path)

print("done")
# Out:
# done

# %%
import os
from PIL import Image
from reportlab.pdfgen import canvas


def image_to_pdf(image_path, pdf_path):
    img = Image.open(image_path)
    width, height = img.size

    pdf_width = width
    pdf_height = height

    c = canvas.Canvas(pdf_path, pagesize=(pdf_width, pdf_height))
    c.drawImage(image_path, 0, 0, width=pdf_width, height=pdf_height)
    c.showPage()
    c.save()


def convert_all_images_to_pdf(input_directory, output_directory):
    # 출력 디렉토리가 없으면 생성
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # 디렉토리 내의 모든 파일에 대해 반복
    for filename in os.listdir(input_directory):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):  # 이미지 파일 확장자
            image_path = os.path.join(input_directory, filename)
            pdf_filename = os.path.splitext(
                filename)[0] + '.pdf'  # PDF 파일 이름 생성
            pdf_path = os.path.join(output_directory, pdf_filename)

            # 이미지 파일을 PDF로 변환
            image_to_pdf(image_path, pdf_path)
            print(f'Converted {filename} to {pdf_filename}')


# 사용 예시
input_directory = './imgs'         # 입력 이미지가 있는 디렉토리
output_directory = './final_pdfs'  # 출력 PDF가 저장될 디렉토리
convert_all_images_to_pdf(input_directory, output_directory)
# Out:
# Converted 학-석사 연계과정.jpg to 학-석사 연계과정.pdf
# Converted K-MOOC 교내 온라인강좌 수강 안내.jpg to K-MOOC 교내 온라인강좌 수강 안내.pdf
# Converted 현장실습학기제 안내.jpg to 현장실습학기제 안내.pdf
# Converted 특별교육과정 (CDP, R.O.T.C., 글로벌인재트랙인증제).jpg to 특별교육과정 (CDP, R.O.T.C., 글로벌인재트랙인증제).pdf
# Converted 다학년 다학기 프로젝트 (KW-VIP) 안내.jpg to 다학년 다학기 프로젝트 (KW-VIP) 안내.pdf
# Converted 수강신청.jpg to 수강신청.pdf
# Converted 편입생이 이수해야 할 교과목 및 학점.jpg to 편입생이 이수해야 할 교과목 및 학점.pdf
# Converted 교양 필수 교과목 수강 안내.jpg to 교양 필수 교과목 수강 안내.pdf
# Converted 참빛설계학기 안내.jpg to 참빛설계학기 안내.pdf
# Converted 연계전공 안내.jpg to 연계전공 안내.pdf
# Converted 다전공 안내.jpg to 다전공 안내.pdf
# Converted 서비스러닝 교과목 안내.jpg to 서비스러닝 교과목 안내.pdf
# Converted 졸업이수학점 안내 (19년 이후 신입학자).jpg to 졸업이수학점 안내 (19년 이후 신입학자).pdf
# Converted 공학교육인증제.jpg to 공학교육인증제.pdf
# Converted 매치업 집중이수제 교내 강좌 수강 안내.jpg to 매치업 집중이수제 교내 강좌 수강 안내.pdf

# %%
import os
import re
from openai import OpenAI
from openai.types.beta.threads.message_create_params import Attachment, AttachmentToolFileSearch
import PRIVATE

client = OpenAI(
    api_key=PRIVATE.api_key
)


def create_file(file_path):
    with open(file_path, 'rb') as f:
        return client.files.create(
            file=f,
            purpose='assistants'
        )


def get_assistant():
    for assistant in client.beta.assistants.list():
        if assistant.name == 'My Assistant Name':
            return assistant

    return client.beta.assistants.create(
        model='gpt-4o-mini',
        description="You must be convert tables and text that appear in a pdf to markdown. When converting to markdown, you never use two spaces in a row or -- twice in a row.",
        instructions="너는 pdf의 전체 내용을 markdown으로 변환하고, 오직 markdown으로만 답을 하는 제일 도움되는 assistant야.",
        tools=[{"type": "file_search"}],
        name='My Assistant Name',
    )


def process_pdf(file_path, assistant_id):
    file = create_file(file_path)
    thread = client.beta.threads.create()

    prompt = "해당 pdf의 표를 markdown 표와 텍스트들을 markdown으로 변환해."
    client.beta.threads.messages.create(
        thread_id=thread.id,
        role='user',
        content=prompt,
        attachments=[Attachment(file_id=file.id, tools=[
                                AttachmentToolFileSearch(type='file_search')])]
    )

    run = client.beta.threads.runs.create_and_poll(
        thread_id=thread.id,
        assistant_id=assistant_id,
        timeout=300,
    )

    if run.status != "completed":
        raise Exception('Run failed:', run.status)

    messages_cursor = client.beta.threads.messages.list(thread_id=thread.id)
    messages = [message for message in messages_cursor]

    message = messages[0]
    assert message.content[0].type == "text"

    res_txt = message.content[0].text.value

    if res_txt.startswith('```markdown'):
        res_txt = res_txt[11:]
    if res_txt.endswith('```'):
        res_txt = res_txt[:-3]

    client.files.delete(file.id)
    return res_txt


def normalize_spaces(text):
    normalized_text = re.sub(r'\s{2,}', ' ', text)
    normalized_text2 = re.sub(r'\s{2,}', '-', normalized_text)
    return normalized_text2


def save_as_md(file_name, content):
    with open(file_name, 'w', encoding='utf-8') as file:
        file.write(content)


def main():
    pdf_dir = './final_pdfs/'
    md_dir = './md/'
    os.makedirs(md_dir, exist_ok=True)

    assistant = get_assistant()

    for pdf_file in os.listdir(pdf_dir):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_dir, pdf_file)
            md_file_name = os.path.splitext(pdf_file)[0] + '.md'
            md_path = os.path.join(md_dir, md_file_name)

            try:
                res_txt = process_pdf(pdf_path, assistant.id)
                normalized_res_txt = normalize_spaces(res_txt)
                save_as_md(md_path, normalized_res_txt)
                print(f'{pdf_file} done')
            except Exception as e:
                print(f'err {pdf_file}: {e}')


if __name__ == "__main__":
    main()
# Out:
# err 특별교육과정 (CDP, R.O.T.C., 글로벌인재트랙인증제).pdf: ('Run failed:', 'failed')
# err 공학교육인증제.pdf: ('Run failed:', 'failed')
# err 졸업이수학점 안내 (19년 이후 신입학자).pdf: ('Run failed:', 'failed')
# err 다학년 다학기 프로젝트 (KW-VIP) 안내.pdf: ('Run failed:', 'failed')
# err 연계전공 안내.pdf: ('Run failed:', 'failed')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 107
#     103                 print(f'err {pdf_file}: {e}')
#     106 if __name__ == "__main__":
# --> 107     main()
#
# Cell In[43], line 98, in main()
#      95 md_path = os.path.join(md_dir, md_file_name)
#      97 try:
# ---> 98     res_txt = process_pdf(pdf_path, assistant.id)
#      99     normalized_res_txt = normalize_spaces(res_txt)
#     100     save_as_md(md_path, normalized_res_txt)
#
# Cell In[43], line 35, in process_pdf(file_path, assistant_id)
#      34 def process_pdf(file_path, assistant_id):
# ---> 35     file = create_file(file_path)
#      36     thread = client.beta.threads.create()
#      38     prompt = "해당 pdf의 표를 markdown 표와 텍스트들을 markdown으로 변환해."
#
# Cell In[43], line 14, in create_file(file_path)
#      12 def create_file(file_path):
#      13     with open(file_path, 'rb') as f:
# ---> 14         return client.files.create(
#      15             file=f,
#      16             purpose='assistants'
#      17         )
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/openai/resources/files.py:118, in Files.create(self, file, purpose, extra_headers, extra_query, extra_body, timeout)
#     114 # It should be noted that the actual Content-Type header that will be
#     115 # sent to the server will contain a `boundary` parameter, e.g.
#     116 # multipart/form-data; boundary=---abc--
#     117 extra_headers = {"Content-Type": "multipart/form-data", **(extra_headers or {})}
# --> 118 return self._post(
#     119     "/files",
#     120     body=maybe_transform(body, file_create_params.FileCreateParams),
#     121     files=files,
#     122     options=make_request_options(
#     123         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     124     ),
#     125     cast_to=FileObject,
#     126 )
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/openai/_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/openai/_base_client.py:942, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     933 def request(
#     934     self,
#     935     cast_to: Type[ResponseT],
#    (...)
#     940     stream_cls: type[_StreamT] | None = None,
#     941 ) -> ResponseT | _StreamT:
# --> 942     return self._request(
#     943         cast_to=cast_to,
#     944         options=options,
#     945         stream=stream,
#     946         stream_cls=stream_cls,
#     947         remaining_retries=remaining_retries,
#     948     )
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/openai/_base_client.py:978, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     975 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     977 try:
# --> 978     response = self._client.send(
#     979         request,
#     980         stream=stream or self._should_stream_response_body(request=request),
#     981         **kwargs,
#     982     )
#     983 except httpx.TimeoutException as err:
#     984     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpx/_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpx/_transports/default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/document/VSCode/kwu-lecture-recommendation-service/.env/lib/python3.11/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File /usr/lib/python3.11/ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File /usr/lib/python3.11/ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
