# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate, ChatPromptTemplate, load_prompt
from langchain.schema import BaseOutputParser
from langchain.callbacks import StreamingStdOutCallbackHandler
from langchain.prompts.few_shot import FewShotPromptTemplate
from langchain.prompts.example_selector import LengthBasedExampleSelector
from langchain.prompts.example_selector.base import BaseExampleSelector
from langchain_core.prompts.few_shot import FewShotPromptTemplate, FewShotChatMessagePromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
import sqlite3
import time

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.05,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()]
)

# %%
example_answer = [
    {
        "question": """
아래는 대학영어 강의에 대한 강의평이야. 강의평을 요약해.
1. 정말 좋은 교수님과 너무 고등학생 같은 시험.. 꼼꼼히 공부해야 합니다!
2. 설명 잘 해주시고 시험은 내신처럼 나옵니다. 꼼꼼히 지문 보세요.
3. 설명 잘해주시고 고등학교 영어 내신처럼 공부하면 됩니다
4. 교수님께서 설명을 친절하게 해주십니다. 2인1조로 구성되어 매수업 해야할 과제가 있지만 강의시간 안에 끝나서 부담이 없습니다. 정말 좋은 교수님이라 추천합니다
5. 기출문제 주십니다. 매 수업 팀 과제가 귀찮아요.  (2인 1조) 쁠은 다 채워주셔요.
""",
        "answer": """
대체로 교수님의 강의력에 대한 긍정적인 평가가 많아요. 친절하고 상세한 설명으로 학생들의 이해를 돕고, 기출문제 제공 등 학습에 도움이 되는 부분도 있어요. 시험은 고등학교 내신처럼 꼼꼼한 암기와 지문 분석을 요구하며, 수업 시간 내에 완료 가능한 2인 1조 팀 과제가 매 수업 있어요. 전반적으로는 좋은 강의이지만, 시험 준비를 철저히 해야 해요.
""",
    },
    {
        "question": """
아래는 광운인되기 강의에 대한 강의평이야. 강의평을 요약해.
1. 강의만 온라인으로 다 들으면 pass주는 과목입니다. 1학점 챙겨가세요
2. 온라인강의 꿀! 학기 말에 몰아서 하면 됩니다!!
3. 강의만 수강하시면 패스 충분히 받습니다. 온라인 강의라 부담이 없습니다
4. 강의 제때제때 틀어놓는 거랑 공지사항 내용 꼼꼼히 확인하기만 하면 쉽게 패스 가능합니다
""",
        "answer": """
광운인되기 강의는 온라인 강의로, 강의만 이수하면 학점 취득이 용이하다는 내용의 긍정적인 평가가 대부분이에요. 학기말에 몰아서 수강해도 무방하며, 강의 시청과 공지사항 확인만으로도 쉽게 패스할 수 있다는 의견이 많아요.
""",
    },
    {
        "question": """
아래는 유기화학1 강의에 대한 강의평이야. 강의평을 요약해.
1. 교수님 강의력 좋은 편은 아님.. 족보 타는 강의 기말은 많이는 안탄듯 가지고 있으면 좋음
2. 족보 너무 많이 탑니다 ㅠ 족보 무조건 구해서 시험 보시는 거 추천드립니다
3. 과제, 족보 이 두개만 풀면 시험 무난하게 볼 수 있어요. 근데 성적을 잘 주시는 편은 아닌 것 같습니다
""",
        "answer": """
유기화학1 강의는 교수님의 강의력이 부족하다는 평가와 함께, 시험에서 족보의 의존도가 매우 높다는 점이 강조되고 있어요. 과제와 족보만 충분히 준비하면 시험을 무난히 볼 수 있지만, 성적 분포는 엄격한 편이에요. 족보 획득이 고득점의 관건이며, 강의 내용보다는 족보 활용에 집중해야 해요.
""",
    },
]

# %%
conn = sqlite3.connect('./kwu-lecture-recommendation-v8.db')
cursor = conn.cursor()


cursor.execute("SELECT DISTINCT lectureID FROM LectureReview")
lecture_ids = cursor.fetchall()


for (lecture_id,) in lecture_ids:
    start_time = time.time()

    cursor.execute(
        """
        SELECT lr.review, ll.lecName 
        FROM LectureReview lr
        JOIN LectureList ll ON lr.lectureID = ll.lectureID
        JOIN LectureEverytimeData led ON lr.lectureID = led.lectureID
        WHERE lr.lectureID = ? AND (led.reviewSummary IS NULL OR led.reviewSummary = '')
        ORDER BY lr.reviewer DESC 
        LIMIT 50;
        """,
        (lecture_id,)
    )

    reviews = cursor.fetchall()

    review_texts = [review[0] for review in reviews]
    lecName = reviews[0][1] if reviews else None

    if len(review_texts) < 3:
        print(f"| pass | {lecture_id} | len(reviews) < 3")
        continue

    output = "\n".join(review_texts)

    print(f"| info | in {lecName} - {lecture_id}")

    question = f"""
    아래는 {lecName} 강의에 대한 강의평이야. 강의평을 요약해.
    {output}
    """

    example_prompt = ChatPromptTemplate.from_messages(
        [
            ("human", "{question}"),
            ("ai", "{answer}"),
        ]
    )

    example_prompt = FewShotChatMessagePromptTemplate(
        example_prompt=example_prompt,
        examples=example_answer,
    )

    final_prompt = ChatPromptTemplate.from_messages(
        [
            ("system", "너는 강의를 선택하는 학생들을 위해 강의 리뷰를 요약하는 봇이야."),
            example_prompt,
            ("human", "강의 리뷰 리스트들을 함축해서 최종적으로 최소 한 줄, 최대 세 줄의 답변만을 내놓아야 해. 여러 리뷰들에서 중복되는 강의의 특징이 나타나거나, 필수적이라고 판단되는 부분만을 한국어로 요약해. 요약 외에는 어떠한 답변도 더하지 마.\n" + question),
        ]
    )

    chain = final_prompt | llm

    answer = chain.invoke({"question": question})

    final_answer = answer.content

    cursor.execute('''
        UPDATE LectureEverytimeData
        SET reviewSummary = ?
        WHERE lectureID = ?
    ''', (final_answer, lecture_id))
    conn.commit()

    if len(final_answer) > 130:
        final_answer = final_answer[:130] + '...'

    print(f"| good | {lecture_id}\t {lecName} \t | {final_answer}")

    end_time = time.time()
    elapsed_time = end_time - start_time
    print(
        f"| time | lectureID: {lecture_id}, elapsed time: {elapsed_time:.2f} seconds |")
    print("|      |")


conn.close()
# Out:
# | pass | 1 | len(reviews) < 3
# | pass | 2 | len(reviews) < 3
# | pass | 3 | len(reviews) < 3
# | pass | 4 | len(reviews) < 3
# | pass | 5 | len(reviews) < 3
# | pass | 6 | len(reviews) < 3
# | pass | 7 | len(reviews) < 3
# | pass | 8 | len(reviews) < 3
# | pass | 9 | len(reviews) < 3
# | pass | 10 | len(reviews) < 3
# | pass | 11 | len(reviews) < 3
# | pass | 12 | len(reviews) < 3
# | pass | 13 | len(reviews) < 3
# | pass | 14 | len(reviews) < 3
# | pass | 15 | len(reviews) < 3
# | pass | 16 | len(reviews) < 3
# | pass | 17 | len(reviews) < 3
# | pass | 18 | len(reviews) < 3
# | pass | 19 | len(reviews) < 3
# | pass | 20 | len(reviews) < 3
# | pass | 21 | len(reviews) < 3
# | pass | 22 | len(reviews) < 3
# | pass | 23 | len(reviews) < 3
# | pass | 24 | len(reviews) < 3
# | pass | 25 | len(reviews) < 3
# | pass | 26 | len(reviews) < 3
# | pass | 27 | len(reviews) < 3
# | pass | 28 | len(reviews) < 3
# | pass | 29 | len(reviews) < 3
# | pass | 30 | len(reviews) < 3
# | pass | 31 | len(reviews) < 3
# | pass | 32 | len(reviews) < 3
# | pass | 33 | len(reviews) < 3
# | pass | 34 | len(reviews) < 3
# | pass | 35 | len(reviews) < 3
# | pass | 36 | len(reviews) < 3
# | pass | 37 | len(reviews) < 3
# | pass | 38 | len(reviews) < 3
# | pass | 39 | len(reviews) < 3
# | pass | 40 | len(reviews) < 3
# | pass | 41 | len(reviews) < 3
# | pass | 42 | len(reviews) < 3
# | pass | 43 | len(reviews) < 3
# | pass | 44 | len(reviews) < 3
# | pass | 45 | len(reviews) < 3
# | pass | 46 | len(reviews) < 3
# | pass | 47 | len(reviews) < 3
# | pass | 48 | len(reviews) < 3
# | pass | 49 | len(reviews) < 3
# | pass | 50 | len(reviews) < 3
# | pass | 51 | len(reviews) < 3
# | pass | 52 | len(reviews) < 3
# | pass | 53 | len(reviews) < 3
# | pass | 54 | len(reviews) < 3
# | pass | 55 | len(reviews) < 3
# | pass | 56 | len(reviews) < 3
# | pass | 57 | len(reviews) < 3
# | pass | 58 | len(reviews) < 3
# | pass | 59 | len(reviews) < 3
# | pass | 60 | len(reviews) < 3
# | pass | 61 | len(reviews) < 3
# | pass | 62 | len(reviews) < 3
# | pass | 63 | len(reviews) < 3
# | pass | 64 | len(reviews) < 3
# | pass | 65 | len(reviews) < 3
# | pass | 66 | len(reviews) < 3
# | pass | 67 | len(reviews) < 3
# | pass | 68 | len(reviews) < 3
# | pass | 69 | len(reviews) < 3
# | pass | 70 | len(reviews) < 3
# | pass | 71 | len(reviews) < 3
# | pass | 72 | len(reviews) < 3
# | pass | 73 | len(reviews) < 3
# | pass | 74 | len(reviews) < 3
# | pass | 75 | len(reviews) < 3
# | pass | 76 | len(reviews) < 3
# | pass | 77 | len(reviews) < 3
# | pass | 78 | len(reviews) < 3
# | pass | 79 | len(reviews) < 3
# | pass | 80 | len(reviews) < 3
# | pass | 81 | len(reviews) < 3
# | pass | 82 | len(reviews) < 3
# | pass | 83 | len(reviews) < 3
# | pass | 84 | len(reviews) < 3
# | pass | 85 | len(reviews) < 3
# | pass | 86 | len(reviews) < 3
# | pass | 87 | len(reviews) < 3
# | pass | 88 | len(reviews) < 3
# | pass | 89 | len(reviews) < 3
# | pass | 90 | len(reviews) < 3
# | pass | 91 | len(reviews) < 3
# | pass | 92 | len(reviews) < 3
# | pass | 93 | len(reviews) < 3
# | pass | 94 | len(reviews) < 3
# | pass | 95 | len(reviews) < 3
# | pass | 96 | len(reviews) < 3
# | pass | 97 | len(reviews) < 3
# | pass | 98 | len(reviews) < 3
# | pass | 99 | len(reviews) < 3
# | pass | 100 | len(reviews) < 3
# | pass | 101 | len(reviews) < 3
# | pass | 102 | len(reviews) < 3
# | pass | 103 | len(reviews) < 3
# | pass | 104 | len(reviews) < 3
# | pass | 105 | len(reviews) < 3
# | pass | 106 | len(reviews) < 3
# | pass | 107 | len(reviews) < 3
# | pass | 108 | len(reviews) < 3
# | pass | 109 | len(reviews) < 3
# | pass | 110 | len(reviews) < 3
# | pass | 111 | len(reviews) < 3
# | pass | 112 | len(reviews) < 3
# | pass | 113 | len(reviews) < 3
# | pass | 114 | len(reviews) < 3
# | pass | 115 | len(reviews) < 3
# | pass | 116 | len(reviews) < 3
# | pass | 117 | len(reviews) < 3
# | pass | 118 | len(reviews) < 3
# | pass | 119 | len(reviews) < 3
# | pass | 120 | len(reviews) < 3
# | pass | 121 | len(reviews) < 3
# | pass | 122 | len(reviews) < 3
# | pass | 123 | len(reviews) < 3
# | pass | 124 | len(reviews) < 3
# | pass | 125 | len(reviews) < 3
# | pass | 126 | len(reviews) < 3
# | pass | 127 | len(reviews) < 3
# | pass | 128 | len(reviews) < 3
# | pass | 129 | len(reviews) < 3
# | pass | 130 | len(reviews) < 3
# | pass | 131 | len(reviews) < 3
# | pass | 132 | len(reviews) < 3
# | pass | 133 | len(reviews) < 3
# | pass | 134 | len(reviews) < 3
# | pass | 135 | len(reviews) < 3
# | pass | 137 | len(reviews) < 3
# | pass | 138 | len(reviews) < 3
# | pass | 139 | len(reviews) < 3
# | pass | 140 | len(reviews) < 3
# | pass | 141 | len(reviews) < 3
# | pass | 142 | len(reviews) < 3
# | pass | 143 | len(reviews) < 3
# | pass | 144 | len(reviews) < 3
# | pass | 145 | len(reviews) < 3
# | pass | 146 | len(reviews) < 3
# | pass | 147 | len(reviews) < 3
# | pass | 148 | len(reviews) < 3
# | pass | 149 | len(reviews) < 3
# | pass | 150 | len(reviews) < 3
# | pass | 151 | len(reviews) < 3
# | pass | 152 | len(reviews) < 3
# | pass | 153 | len(reviews) < 3
# | pass | 154 | len(reviews) < 3
# | pass | 155 | len(reviews) < 3
# | pass | 156 | len(reviews) < 3
# | pass | 157 | len(reviews) < 3
# | pass | 158 | len(reviews) < 3
# | pass | 159 | len(reviews) < 3
# | pass | 160 | len(reviews) < 3
# | pass | 161 | len(reviews) < 3
# | pass | 162 | len(reviews) < 3
# | pass | 163 | len(reviews) < 3
# | pass | 164 | len(reviews) < 3
# | pass | 165 | len(reviews) < 3
# | pass | 167 | len(reviews) < 3
# | pass | 168 | len(reviews) < 3
# | pass | 169 | len(reviews) < 3
# | pass | 170 | len(reviews) < 3
# | pass | 171 | len(reviews) < 3
# | pass | 172 | len(reviews) < 3
# | pass | 173 | len(reviews) < 3
# | pass | 174 | len(reviews) < 3
# | pass | 175 | len(reviews) < 3
# | pass | 176 | len(reviews) < 3
# | pass | 177 | len(reviews) < 3
# | pass | 178 | len(reviews) < 3
# | pass | 180 | len(reviews) < 3
# | pass | 181 | len(reviews) < 3
# | pass | 182 | len(reviews) < 3
# | pass | 183 | len(reviews) < 3
# | pass | 184 | len(reviews) < 3
# | pass | 185 | len(reviews) < 3
# | pass | 186 | len(reviews) < 3
# | pass | 188 | len(reviews) < 3
# | pass | 189 | len(reviews) < 3
# | pass | 190 | len(reviews) < 3
# | pass | 191 | len(reviews) < 3
# | pass | 192 | len(reviews) < 3
# | pass | 193 | len(reviews) < 3
# | pass | 194 | len(reviews) < 3
# | pass | 195 | len(reviews) < 3
# | pass | 196 | len(reviews) < 3
# | pass | 197 | len(reviews) < 3
# | pass | 198 | len(reviews) < 3
# | pass | 199 | len(reviews) < 3
# | pass | 200 | len(reviews) < 3
# | pass | 201 | len(reviews) < 3
# | pass | 202 | len(reviews) < 3
# | pass | 203 | len(reviews) < 3
# | pass | 204 | len(reviews) < 3
# | pass | 205 | len(reviews) < 3
# | pass | 206 | len(reviews) < 3
# | pass | 207 | len(reviews) < 3
# | pass | 208 | len(reviews) < 3
# | pass | 209 | len(reviews) < 3
# | pass | 210 | len(reviews) < 3
# | pass | 211 | len(reviews) < 3
# | pass | 212 | len(reviews) < 3
# | pass | 213 | len(reviews) < 3
# | pass | 214 | len(reviews) < 3
# | pass | 215 | len(reviews) < 3
# | pass | 216 | len(reviews) < 3
# | pass | 217 | len(reviews) < 3
# | pass | 218 | len(reviews) < 3
# | pass | 219 | len(reviews) < 3
# | pass | 220 | len(reviews) < 3
# | pass | 221 | len(reviews) < 3
# | pass | 222 | len(reviews) < 3
# | pass | 223 | len(reviews) < 3
# | pass | 224 | len(reviews) < 3
# | pass | 225 | len(reviews) < 3
# | pass | 226 | len(reviews) < 3
# | pass | 227 | len(reviews) < 3
# | pass | 228 | len(reviews) < 3
# | pass | 229 | len(reviews) < 3
# | pass | 230 | len(reviews) < 3
# | pass | 231 | len(reviews) < 3
# | pass | 232 | len(reviews) < 3
# | pass | 234 | len(reviews) < 3
# | pass | 235 | len(reviews) < 3
# | pass | 236 | len(reviews) < 3
# | pass | 237 | len(reviews) < 3
# | pass | 238 | len(reviews) < 3
# | pass | 239 | len(reviews) < 3
# | pass | 240 | len(reviews) < 3
# | pass | 241 | len(reviews) < 3
# | pass | 242 | len(reviews) < 3
# | pass | 243 | len(reviews) < 3
# | pass | 244 | len(reviews) < 3
# | pass | 245 | len(reviews) < 3
# | pass | 246 | len(reviews) < 3
# | pass | 247 | len(reviews) < 3
# | pass | 248 | len(reviews) < 3
# | pass | 249 | len(reviews) < 3
# | pass | 250 | len(reviews) < 3
# | pass | 251 | len(reviews) < 3
# | pass | 252 | len(reviews) < 3
# | pass | 253 | len(reviews) < 3
# | pass | 254 | len(reviews) < 3
# | pass | 255 | len(reviews) < 3
# | pass | 256 | len(reviews) < 3
# | pass | 257 | len(reviews) < 3
# | pass | 258 | len(reviews) < 3
# | pass | 259 | len(reviews) < 3
# | pass | 260 | len(reviews) < 3
# | pass | 261 | len(reviews) < 3
# | pass | 262 | len(reviews) < 3
# | pass | 263 | len(reviews) < 3
# | pass | 264 | len(reviews) < 3
# | pass | 265 | len(reviews) < 3
# | pass | 266 | len(reviews) < 3
# | pass | 267 | len(reviews) < 3
# | pass | 268 | len(reviews) < 3
# | pass | 269 | len(reviews) < 3
# | pass | 270 | len(reviews) < 3
# | pass | 271 | len(reviews) < 3
# | pass | 272 | len(reviews) < 3
# | pass | 273 | len(reviews) < 3
# | pass | 274 | len(reviews) < 3
# | pass | 275 | len(reviews) < 3
# | pass | 276 | len(reviews) < 3
# | pass | 277 | len(reviews) < 3
# | pass | 278 | len(reviews) < 3
# | pass | 279 | len(reviews) < 3
# | pass | 280 | len(reviews) < 3
# | pass | 281 | len(reviews) < 3
# | pass | 282 | len(reviews) < 3
# | pass | 283 | len(reviews) < 3
# | pass | 284 | len(reviews) < 3
# | pass | 285 | len(reviews) < 3
# | pass | 286 | len(reviews) < 3
# | pass | 287 | len(reviews) < 3
# | pass | 288 | len(reviews) < 3
# | pass | 289 | len(reviews) < 3
# | pass | 290 | len(reviews) < 3
# | pass | 291 | len(reviews) < 3
# | pass | 292 | len(reviews) < 3
# | pass | 293 | len(reviews) < 3
# | pass | 294 | len(reviews) < 3
# | pass | 295 | len(reviews) < 3
# | pass | 296 | len(reviews) < 3
# | pass | 298 | len(reviews) < 3
# | pass | 299 | len(reviews) < 3
# | pass | 300 | len(reviews) < 3
# | pass | 301 | len(reviews) < 3
# | pass | 302 | len(reviews) < 3
# | pass | 303 | len(reviews) < 3
# | pass | 304 | len(reviews) < 3
# | pass | 305 | len(reviews) < 3
# | pass | 306 | len(reviews) < 3
# | pass | 307 | len(reviews) < 3
# | pass | 308 | len(reviews) < 3
# | pass | 309 | len(reviews) < 3
# | pass | 310 | len(reviews) < 3
# | pass | 311 | len(reviews) < 3
# | pass | 312 | len(reviews) < 3
# | pass | 313 | len(reviews) < 3
# | pass | 314 | len(reviews) < 3
# | pass | 315 | len(reviews) < 3
# | pass | 316 | len(reviews) < 3
# | pass | 317 | len(reviews) < 3
# | pass | 318 | len(reviews) < 3
# | pass | 319 | len(reviews) < 3
# | pass | 320 | len(reviews) < 3
# | pass | 321 | len(reviews) < 3
# | pass | 322 | len(reviews) < 3
# | pass | 323 | len(reviews) < 3
# | pass | 324 | len(reviews) < 3
# | pass | 325 | len(reviews) < 3
# | pass | 326 | len(reviews) < 3
# | pass | 327 | len(reviews) < 3
# | pass | 328 | len(reviews) < 3
# | pass | 329 | len(reviews) < 3
# | pass | 330 | len(reviews) < 3
# | pass | 331 | len(reviews) < 3
# | pass | 332 | len(reviews) < 3
# | pass | 333 | len(reviews) < 3
# | pass | 334 | len(reviews) < 3
# | pass | 335 | len(reviews) < 3
# | pass | 336 | len(reviews) < 3
# | pass | 337 | len(reviews) < 3
# | pass | 338 | len(reviews) < 3
# | pass | 340 | len(reviews) < 3
# | pass | 342 | len(reviews) < 3
# | pass | 343 | len(reviews) < 3
# | pass | 344 | len(reviews) < 3
# | pass | 345 | len(reviews) < 3
# | pass | 346 | len(reviews) < 3
# | pass | 347 | len(reviews) < 3
# | pass | 348 | len(reviews) < 3
# | pass | 349 | len(reviews) < 3
# | pass | 350 | len(reviews) < 3
# | pass | 351 | len(reviews) < 3
# | pass | 352 | len(reviews) < 3
# | pass | 353 | len(reviews) < 3
# | pass | 354 | len(reviews) < 3
# | pass | 355 | len(reviews) < 3
# | pass | 356 | len(reviews) < 3
# | pass | 357 | len(reviews) < 3
# | pass | 358 | len(reviews) < 3
# | pass | 359 | len(reviews) < 3
# | pass | 360 | len(reviews) < 3
# | pass | 361 | len(reviews) < 3
# | pass | 362 | len(reviews) < 3
# | pass | 363 | len(reviews) < 3
# | pass | 364 | len(reviews) < 3
# | pass | 365 | len(reviews) < 3
# | pass | 366 | len(reviews) < 3
# | pass | 367 | len(reviews) < 3
# | pass | 368 | len(reviews) < 3
# | pass | 369 | len(reviews) < 3
# | pass | 370 | len(reviews) < 3
# | pass | 371 | len(reviews) < 3
# | pass | 372 | len(reviews) < 3
# | pass | 373 | len(reviews) < 3
# | pass | 374 | len(reviews) < 3
# | pass | 375 | len(reviews) < 3
# | pass | 376 | len(reviews) < 3
# | pass | 377 | len(reviews) < 3
# | pass | 378 | len(reviews) < 3
# | pass | 379 | len(reviews) < 3
# | pass | 380 | len(reviews) < 3
# | pass | 381 | len(reviews) < 3
# | pass | 382 | len(reviews) < 3
# | pass | 383 | len(reviews) < 3
# | pass | 385 | len(reviews) < 3
# | pass | 386 | len(reviews) < 3
# | pass | 387 | len(reviews) < 3
# | pass | 389 | len(reviews) < 3
# | pass | 390 | len(reviews) < 3
# | pass | 391 | len(reviews) < 3
# | pass | 392 | len(reviews) < 3
# | pass | 393 | len(reviews) < 3
# | pass | 394 | len(reviews) < 3
# | pass | 395 | len(reviews) < 3
# | pass | 396 | len(reviews) < 3
# | pass | 397 | len(reviews) < 3
# | pass | 398 | len(reviews) < 3
# | pass | 399 | len(reviews) < 3
# | pass | 400 | len(reviews) < 3
# | pass | 402 | len(reviews) < 3
# | pass | 403 | len(reviews) < 3
# | pass | 404 | len(reviews) < 3
# | pass | 405 | len(reviews) < 3
# | pass | 406 | len(reviews) < 3
# | pass | 407 | len(reviews) < 3
# | pass | 408 | len(reviews) < 3
# | pass | 409 | len(reviews) < 3
# | pass | 410 | len(reviews) < 3
# | pass | 411 | len(reviews) < 3
# | pass | 412 | len(reviews) < 3
# | pass | 413 | len(reviews) < 3
# | pass | 414 | len(reviews) < 3
# | pass | 415 | len(reviews) < 3
# | pass | 417 | len(reviews) < 3
# | pass | 418 | len(reviews) < 3
# | pass | 419 | len(reviews) < 3
# | pass | 420 | len(reviews) < 3
# | pass | 421 | len(reviews) < 3
# | pass | 422 | len(reviews) < 3
# | pass | 423 | len(reviews) < 3
# | pass | 424 | len(reviews) < 3
# | pass | 425 | len(reviews) < 3
# | pass | 426 | len(reviews) < 3
# | pass | 427 | len(reviews) < 3
# | pass | 428 | len(reviews) < 3
# | pass | 429 | len(reviews) < 3
# | pass | 430 | len(reviews) < 3
# | pass | 431 | len(reviews) < 3
# | pass | 432 | len(reviews) < 3
# | pass | 433 | len(reviews) < 3
# | pass | 434 | len(reviews) < 3
# | pass | 435 | len(reviews) < 3
# | pass | 436 | len(reviews) < 3
# | pass | 437 | len(reviews) < 3
# | pass | 438 | len(reviews) < 3
# | pass | 439 | len(reviews) < 3
# | pass | 440 | len(reviews) < 3
# | pass | 441 | len(reviews) < 3
# | pass | 442 | len(reviews) < 3
# | pass | 443 | len(reviews) < 3
# | pass | 444 | len(reviews) < 3
# | pass | 445 | len(reviews) < 3
# | pass | 446 | len(reviews) < 3
# | pass | 447 | len(reviews) < 3
# | pass | 448 | len(reviews) < 3
# | pass | 449 | len(reviews) < 3
# | pass | 455 | len(reviews) < 3
# | pass | 460 | len(reviews) < 3
# | pass | 461 | len(reviews) < 3
# | pass | 462 | len(reviews) < 3
# | pass | 465 | len(reviews) < 3
# | pass | 467 | len(reviews) < 3
# | pass | 468 | len(reviews) < 3
# | pass | 469 | len(reviews) < 3
# | pass | 470 | len(reviews) < 3
# | pass | 471 | len(reviews) < 3
# | pass | 472 | len(reviews) < 3
# | pass | 473 | len(reviews) < 3
# | pass | 474 | len(reviews) < 3
# | pass | 475 | len(reviews) < 3
# | pass | 476 | len(reviews) < 3
# | pass | 477 | len(reviews) < 3
# | pass | 478 | len(reviews) < 3
# | pass | 479 | len(reviews) < 3
# | pass | 480 | len(reviews) < 3
# | pass | 481 | len(reviews) < 3
# | pass | 482 | len(reviews) < 3
# | pass | 483 | len(reviews) < 3
# | pass | 484 | len(reviews) < 3
# | pass | 485 | len(reviews) < 3
# | pass | 486 | len(reviews) < 3
# | pass | 487 | len(reviews) < 3
# | pass | 488 | len(reviews) < 3
# | pass | 489 | len(reviews) < 3
# | pass | 490 | len(reviews) < 3
# | pass | 491 | len(reviews) < 3
# | pass | 492 | len(reviews) < 3
# | pass | 493 | len(reviews) < 3
# | pass | 494 | len(reviews) < 3
# | pass | 495 | len(reviews) < 3
# | pass | 496 | len(reviews) < 3
# | pass | 497 | len(reviews) < 3
# | pass | 498 | len(reviews) < 3
# | pass | 499 | len(reviews) < 3
# | pass | 500 | len(reviews) < 3
# | pass | 501 | len(reviews) < 3
# | pass | 502 | len(reviews) < 3
# | pass | 503 | len(reviews) < 3
# | pass | 504 | len(reviews) < 3
# | pass | 505 | len(reviews) < 3
# | pass | 506 | len(reviews) < 3
# | pass | 507 | len(reviews) < 3
# | pass | 508 | len(reviews) < 3
# | pass | 509 | len(reviews) < 3
# | pass | 510 | len(reviews) < 3
# | pass | 511 | len(reviews) < 3
# | pass | 512 | len(reviews) < 3
# | pass | 513 | len(reviews) < 3
# | pass | 514 | len(reviews) < 3
# | pass | 515 | len(reviews) < 3
# | pass | 516 | len(reviews) < 3
# | pass | 517 | len(reviews) < 3
# | pass | 518 | len(reviews) < 3
# | pass | 519 | len(reviews) < 3
# | pass | 521 | len(reviews) < 3
# | pass | 522 | len(reviews) < 3
# | pass | 523 | len(reviews) < 3
# | pass | 524 | len(reviews) < 3
# | pass | 525 | len(reviews) < 3
# | pass | 526 | len(reviews) < 3
# | pass | 527 | len(reviews) < 3
# | pass | 528 | len(reviews) < 3
# | info | in 물리전자1 - 529
# 물리전자1 강의는 교수님의 강의력이 좋고 설명이 깔끔하다는 평가가 많으며, 오픈북 퀴즈와 과제가 없어 부담이 적습니다. 시험은 변별력이 있으며, 개념과 수식을 잘 이해해야 좋은 성적을 받을 수 있습니다. 수업 내용을 잘 따라가면 학점이 잘 나오는 편입니다.| good | 529	 물리전자1 	 | 물리전자1 강의는 교수님의 강의력이 좋고 설명이 깔끔하다는 평가가 많으며, 오픈북 퀴즈와 과제가 없어 부담이 적습니다. 시험은 변별력이 있으며, 개념과 수식을 잘 이해해야 좋은 성적을 받을 수 있습니다. 수업 내용을 잘 따라가면 학점...
# | time | lectureID: 529, elapsed time: 3.89 seconds |
# |      |
# | info | in 진로탐색및설계 - 530
# 진로탐색및설계 강의는 시험이 없고, 중간과 기말에 과제만 제출하면 쉽게 1학점을 취득할 수 있는 편한 과목입니다. 강의를 틀어놓기만 해도 학점을 받을 수 있어 부담이 적고, 유용한 정보도 제공받는다는 긍정적인 평가가 많습니다.| good | 530	 진로탐색및설계 	 | 진로탐색및설계 강의는 시험이 없고, 중간과 기말에 과제만 제출하면 쉽게 1학점을 취득할 수 있는 편한 과목입니다. 강의를 틀어놓기만 해도 학점을 받을 수 있어 부담이 적고, 유용한 정보도 제공받는다는 긍정적인 평가가 많습니다.
# | time | lectureID: 530, elapsed time: 1.89 seconds |
# |      |
# | info | in 전자기학1 - 531
# 전자기학1 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이나, 수업 내용이 난해하고 과제가 많아 부담이 클 수 있습니다. 시험 문제는 예제와 과제에서 출제되므로, 이를 철저히 준비하면 좋은 성적을 받을 수 있지만, A+은 받기 어려운 편입니다. 수업에 집중하지 않으면 따라가기 힘들 수 있으니 주의가 필요합니다.| good | 531	 전자기학1 	 | 전자기학1 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이나, 수업 내용이 난해하고 과제가 많아 부담이 클 수 있습니다. 시험 문제는 예제와 과제에서 출제되므로, 이를 철저히 준비하면 좋은 성적을 받을 수 있지만, A+은 받기 ...
# | time | lectureID: 531, elapsed time: 2.30 seconds |
# |      |
# | info | in 전자기학1 - 532
# 전자기학1 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이나, 수업 내용이 난해하고 과제가 많아 부담이 클 수 있습니다. 시험 문제는 예제와 과제에서 출제되므로, 이를 잘 준비하면 좋은 성적을 받을 수 있지만, 성적은 다소 엄격하게 평가됩니다. 집중력이 떨어지면 수업을 따라가기 어려울 수 있으니 주의가 필요합니다.| good | 532	 전자기학1 	 | 전자기학1 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이나, 수업 내용이 난해하고 과제가 많아 부담이 클 수 있습니다. 시험 문제는 예제와 과제에서 출제되므로, 이를 잘 준비하면 좋은 성적을 받을 수 있지만, 성적은 다소 엄격...
# | time | lectureID: 532, elapsed time: 2.00 seconds |
# |      |
# | info | in 회로이론1 - 533
# 회로이론1 강의는 김복기 교수님의 열정적인 강의와 높은 강의력이 특징입니다. 과제와 예제에서 시험 문제가 주로 출제되며, 성적은 과제와 시험 준비에 따라 잘 받을 수 있지만 플러스 학점은 기대하기 어려운 편입니다. 강의량이 많고 진도가 빠르기 때문에 꾸준한 복습이 필요합니다.| good | 533	 회로이론1 	 | 회로이론1 강의는 김복기 교수님의 열정적인 강의와 높은 강의력이 특징입니다. 과제와 예제에서 시험 문제가 주로 출제되며, 성적은 과제와 시험 준비에 따라 잘 받을 수 있지만 플러스 학점은 기대하기 어려운 편입니다. 강의량이 많고 진도...
# | time | lectureID: 533, elapsed time: 2.18 seconds |
# |      |
# | info | in 회로이론1 - 534
# 회로이론1 강의는 과제를 잘 풀면 좋은 성적을 받을 수 있으며, 시험은 과제와 예제 문제 위주로 출제됩니다. 교수님의 강의력은 다소 부족하다는 평가가 많지만, 학생들을 배려하는 모습이 긍정적으로 언급됩니다. 전반적으로 무난한 강의로, 독학이 필요할 수 있습니다.| good | 534	 회로이론1 	 | 회로이론1 강의는 과제를 잘 풀면 좋은 성적을 받을 수 있으며, 시험은 과제와 예제 문제 위주로 출제됩니다. 교수님의 강의력은 다소 부족하다는 평가가 많지만, 학생들을 배려하는 모습이 긍정적으로 언급됩니다. 전반적으로 무난한 강의로,...
# | time | lectureID: 534, elapsed time: 2.22 seconds |
# |      |
# | info | in 회로이론1 - 535
# 회로이론1 강의는 온라인과 대면 수업이 병행되며, 출석 체크가 거의 없고 문제풀이 위주로 진행됩니다. 교수님의 강의력은 좋지만 시험 난이도가 높고 성적이 깐깐하게 주어지는 편입니다. 과제를 잘 풀고 예제 문제를 연습하면 좋은 성적을 받을 수 있습니다.| good | 535	 회로이론1 	 | 회로이론1 강의는 온라인과 대면 수업이 병행되며, 출석 체크가 거의 없고 문제풀이 위주로 진행됩니다. 교수님의 강의력은 좋지만 시험 난이도가 높고 성적이 깐깐하게 주어지는 편입니다. 과제를 잘 풀고 예제 문제를 연습하면 좋은 성적을 ...
# | time | lectureID: 535, elapsed time: 1.71 seconds |
# |      |
# | info | in 기초전자회로및실험1 - 536
# 기초전자회로및실험1 강의는 레포트와 실험, 텀 프로젝트가 많아 과제가 부담스럽지만, 시험 성적이 좋으면 학점이 잘 나오는 편입니다. 교수님보다 조교의 영향이 크며, 조원과의 협력이 중요합니다. 기본 개념만 알고 가면 수월하게 진행할 수 있습니다.| good | 536	 기초전자회로및실험1 	 | 기초전자회로및실험1 강의는 레포트와 실험, 텀 프로젝트가 많아 과제가 부담스럽지만, 시험 성적이 좋으면 학점이 잘 나오는 편입니다. 교수님보다 조교의 영향이 크며, 조원과의 협력이 중요합니다. 기본 개념만 알고 가면 수월하게 진행할 ...
# | time | lectureID: 536, elapsed time: 1.72 seconds |
# |      |
# | info | in 기초전자회로및실험1 - 537
# 기초전자회로및실험1 강의는 교수님에 대한 중요성이 낮고, 실험과 레포트가 많아 시간과 노력이 많이 드는 과목입니다. 시험이 성적에 큰 영향을 미치며, 레포트는 컴퓨터로 작성하지만 양이 많아 부담이 큽니다. 조교가 수업을 진행하고 채점하는 방식이 다르므로 팀원 선택이 중요합니다.| good | 537	 기초전자회로및실험1 	 | 기초전자회로및실험1 강의는 교수님에 대한 중요성이 낮고, 실험과 레포트가 많아 시간과 노력이 많이 드는 과목입니다. 시험이 성적에 큰 영향을 미치며, 레포트는 컴퓨터로 작성하지만 양이 많아 부담이 큽니다. 조교가 수업을 진행하고 채점...
# | time | lectureID: 537, elapsed time: 2.23 seconds |
# |      |
# | info | in 기초전자회로및실험1 - 538
# 기초전자회로및실험1 강의는 조교의 친절함이 돋보이며, 실험과 텀프, 시험이 모두 중요하지만 중간과 기말 시험이 성적에 큰 영향을 미칩니다. 조원 선택이 중요하고, 출석 관리가 엄격하니 주의해야 합니다. 레포트와 텀프는 완성만 하면 되지만, 시험 준비는 미리 해야 좋은 성적을 받을 수 있습니다.| good | 538	 기초전자회로및실험1 	 | 기초전자회로및실험1 강의는 조교의 친절함이 돋보이며, 실험과 텀프, 시험이 모두 중요하지만 중간과 기말 시험이 성적에 큰 영향을 미칩니다. 조원 선택이 중요하고, 출석 관리가 엄격하니 주의해야 합니다. 레포트와 텀프는 완성만 하면 되...
# | time | lectureID: 538, elapsed time: 2.02 seconds |
# |      |
# | info | in 기초전자회로및실험1 - 539
# 기초전자회로및실험1 강의는 매주 레포트와 팀 프로젝트(텀프)가 있으며, 시험 비중이 크고 성적은 시험에 따라 좌우됩니다. 레포트 작성이 귀찮지만, 시험 준비는 회로이론과 디지털 공학과 연계되어 상대적으로 수월하다는 의견이 많습니다. 조원과의 협력이 중요하며, 시험을 잘 보면 좋은 성적을 받을 수 있습니다.| good | 539	 기초전자회로및실험1 	 | 기초전자회로및실험1 강의는 매주 레포트와 팀 프로젝트(텀프)가 있으며, 시험 비중이 크고 성적은 시험에 따라 좌우됩니다. 레포트 작성이 귀찮지만, 시험 준비는 회로이론과 디지털 공학과 연계되어 상대적으로 수월하다는 의견이 많습니다. ...
# | time | lectureID: 539, elapsed time: 2.03 seconds |
# |      |
# | info | in 기초전자회로및실험1 - 540
# 기초전자회로및실험1 강의는 매주 레포트와 시험이 많아 과제가 상당히 부담스럽고, 조교의 불친절함과 성적 분배가 깐깐하다는 평가가 많습니다. 실험과 텀프 발표는 무난하게 진행되지만, 레포트 작성이 특히 어렵고 시간이 많이 소요됩니다. 성적은 개인의 노력에 따라 달라지며, 열심히 공부하면 좋은 결과를 얻을 수 있습니다.| good | 540	 기초전자회로및실험1 	 | 기초전자회로및실험1 강의는 매주 레포트와 시험이 많아 과제가 상당히 부담스럽고, 조교의 불친절함과 성적 분배가 깐깐하다는 평가가 많습니다. 실험과 텀프 발표는 무난하게 진행되지만, 레포트 작성이 특히 어렵고 시간이 많이 소요됩니다. ...
# | time | lectureID: 540, elapsed time: 2.15 seconds |
# |      |
# | info | in 마이크로파공학 - 541
# 마이크로파공학 강의는 교수님의 강의력이 좋고, 수업 내용을 잘 따라가면 좋은 성적을 받을 수 있습니다. 시험은 상대적으로 쉬운 편이며, 족보에 의존하는 경향이 강해 족보를 구하는 것이 중요합니다. 과제는 적당하고, 수업 내용이 전공 이해에 도움이 되는 점이 긍정적으로 평가됩니다.| good | 541	 마이크로파공학 	 | 마이크로파공학 강의는 교수님의 강의력이 좋고, 수업 내용을 잘 따라가면 좋은 성적을 받을 수 있습니다. 시험은 상대적으로 쉬운 편이며, 족보에 의존하는 경향이 강해 족보를 구하는 것이 중요합니다. 과제는 적당하고, 수업 내용이 전공 ...
# | time | lectureID: 541, elapsed time: 2.24 seconds |
# |      |
# | info | in 전자회로1 - 542
# 전자회로1 강의는 교수님의 강의력이 좋고 친절하다는 평가가 많지만, 판서가 부족하고 졸릴 수 있다는 단점이 있습니다. 시험은 응용문제가 많고 난이도가 다소 어려운 편이며, 강의자료와 과제를 충실히 준비하면 좋은 성적을 받을 수 있습니다. 학생들에 대한 애정이 넘치는 교수님이지만, 성적은 노력에 따라 달라질 수 있습니다.| good | 542	 전자회로1 	 | 전자회로1 강의는 교수님의 강의력이 좋고 친절하다는 평가가 많지만, 판서가 부족하고 졸릴 수 있다는 단점이 있습니다. 시험은 응용문제가 많고 난이도가 다소 어려운 편이며, 강의자료와 과제를 충실히 준비하면 좋은 성적을 받을 수 있습니...
# | time | lectureID: 542, elapsed time: 2.73 seconds |
# |      |
# | info | in 전자회로1 - 543
# 전자회로1 강의는 교수님의 강의력이 뛰어나지만 진도가 빠르고 시험 난이도가 높아 철저한 준비가 필요합니다. 과제는 제출 여부만 확인되며, 시험 문제는 주로 과제와 교재에서 출제됩니다. 성적은 변별력이 있으며, 기본 개념 이해가 중요합니다.| good | 543	 전자회로1 	 | 전자회로1 강의는 교수님의 강의력이 뛰어나지만 진도가 빠르고 시험 난이도가 높아 철저한 준비가 필요합니다. 과제는 제출 여부만 확인되며, 시험 문제는 주로 과제와 교재에서 출제됩니다. 성적은 변별력이 있으며, 기본 개념 이해가 중요합...
# | time | lectureID: 543, elapsed time: 1.95 seconds |
# |      |
# | info | in 전자회로실험 - 544
# 전자회로실험 강의는 조교의 평가 기준이 애매하고, 조원 구성이 중요하다는 의견이 많아요. 조교와의 관계에 따라 실험의 난이도가 달라질 수 있으며, 레포트는 수기로 작성해야 합니다. 전반적으로 조원 복불복이 큰 영향을 미치는 필수 과목입니다.| good | 544	 전자회로실험 	 | 전자회로실험 강의는 조교의 평가 기준이 애매하고, 조원 구성이 중요하다는 의견이 많아요. 조교와의 관계에 따라 실험의 난이도가 달라질 수 있으며, 레포트는 수기로 작성해야 합니다. 전반적으로 조원 복불복이 큰 영향을 미치는 필수 과목...
# | time | lectureID: 544, elapsed time: 1.58 seconds |
# |      |
# | info | in 전자회로실험 - 545
# 전자회로실험 강의는 자유주제로 진행되는 텀 프로젝트가 주요 평가 요소이며, 교수님의 질문이 까다롭고 발표에서의 압박이 크다는 평가가 많습니다. 과제와 텀 프로젝트의 완성도가 중요하며, 창의적인 접근이 요구됩니다. 전반적으로 스트레스가 크지만, 학점은 비교적 잘 주는 편입니다.| good | 545	 전자회로실험 	 | 전자회로실험 강의는 자유주제로 진행되는 텀 프로젝트가 주요 평가 요소이며, 교수님의 질문이 까다롭고 발표에서의 압박이 크다는 평가가 많습니다. 과제와 텀 프로젝트의 완성도가 중요하며, 창의적인 접근이 요구됩니다. 전반적으로 스트레스가...
# | time | lectureID: 545, elapsed time: 1.60 seconds |
# |      |
# | info | in 전자회로실험 - 546
# 전자회로실험 강의는 텀프의 비중이 매우 높아 성적에 큰 영향을 미치며, 시험은 전자회로 내용을 잘 이해하면 쉽게 풀 수 있습니다. 조교의 역할이 중요하고, 실험 장비나 레포트 작성에서의 불편함이 언급되었으며, 전반적으로 교수님의 강의는 아쉬운 평가를 받고 있습니다.| good | 546	 전자회로실험 	 | 전자회로실험 강의는 텀프의 비중이 매우 높아 성적에 큰 영향을 미치며, 시험은 전자회로 내용을 잘 이해하면 쉽게 풀 수 있습니다. 조교의 역할이 중요하고, 실험 장비나 레포트 작성에서의 불편함이 언급되었으며, 전반적으로 교수님의 강의...
# | time | lectureID: 546, elapsed time: 2.15 seconds |
# |      |
# | info | in 전자회로실험 - 547
# 전자회로실험 강의는 외국인 조교와의 소통이 어려운 점이 있지만, 금요일 수업이라는 장점이 있습니다. 텀 프로젝트의 비중이 높아져서 이를 잘 수행하면 좋은 성적을 받을 수 있으며, 레포트 작성이 중요합니다. 전반적으로 무난한 실험 과목으로 평가되지만, 조교의 수준 차이와 공지 지연 등으로 불편함을 느끼는 학생들이 많습니다.| good | 547	 전자회로실험 	 | 전자회로실험 강의는 외국인 조교와의 소통이 어려운 점이 있지만, 금요일 수업이라는 장점이 있습니다. 텀 프로젝트의 비중이 높아져서 이를 잘 수행하면 좋은 성적을 받을 수 있으며, 레포트 작성이 중요합니다. 전반적으로 무난한 실험 과목...
# | time | lectureID: 547, elapsed time: 2.48 seconds |
# |      |
# | info | in 전자회로실험 - 548
# 전자회로실험 강의에서 텀프로젝트의 비중이 매우 높으며, 이를 잘 수행해야 좋은 성적을 받을 수 있습니다. 시험은 상대적으로 쉬운 편이지만, 텀프에서 낮은 점수를 받으면 성적에 큰 영향을 미치므로 주의가 필요합니다. 조교님들이 친절하게 설명해주며, 실용성과 창의성이 강조됩니다.| good | 548	 전자회로실험 	 | 전자회로실험 강의에서 텀프로젝트의 비중이 매우 높으며, 이를 잘 수행해야 좋은 성적을 받을 수 있습니다. 시험은 상대적으로 쉬운 편이지만, 텀프에서 낮은 점수를 받으면 성적에 큰 영향을 미치므로 주의가 필요합니다. 조교님들이 친절하게...
# | time | lectureID: 548, elapsed time: 2.85 seconds |
# |      |
# | info | in 통신이론1 - 549
# 통신이론1 강의는 박호종 교수님의 강의력이 뛰어나고, 오픈북 시험으로 암기 부담이 적지만, 시험 난이도가 높아 철저한 준비가 필요합니다. C언어를 활용한 과제가 3번 있으며, 과제는 어렵지 않지만 기본적인 코딩 지식이 요구됩니다. 신호 및 시스템 과목의 복습이 중요하며, 개념 이해가 시험 성적에 큰 영향을 미칩니다.| good | 549	 통신이론1 	 | 통신이론1 강의는 박호종 교수님의 강의력이 뛰어나고, 오픈북 시험으로 암기 부담이 적지만, 시험 난이도가 높아 철저한 준비가 필요합니다. C언어를 활용한 과제가 3번 있으며, 과제는 어렵지 않지만 기본적인 코딩 지식이 요구됩니다. 신...
# | time | lectureID: 549, elapsed time: 2.13 seconds |
# |      |
# | info | in 경력개발과취업전략 - 550
# 경력개발과취업전략 강의는 출석과 자소서 작성만으로 쉽게 전공 2학점을 취득할 수 있는 수업입니다. 시험이 없고, 중간고사 이후에는 비대면 강의로 진행되어 부담이 적으며, 취업 관련 정보도 제공받을 수 있어 유익하다는 평가가 많습니다. 전반적으로 편하게 듣기 좋은 강의로 추천됩니다.| good | 550	 경력개발과취업전략 	 | 경력개발과취업전략 강의는 출석과 자소서 작성만으로 쉽게 전공 2학점을 취득할 수 있는 수업입니다. 시험이 없고, 중간고사 이후에는 비대면 강의로 진행되어 부담이 적으며, 취업 관련 정보도 제공받을 수 있어 유익하다는 평가가 많습니다....
# | time | lectureID: 550, elapsed time: 2.80 seconds |
# |      |
# | info | in 반도체소자및설계 - 551
# 반도체소자및설계 강의는 박재우 교수님의 강의력에 대한 긍정적인 평가가 많지만, 성적 산출에 대한 아쉬움이 존재합니다. 강의는 기초부터 자세히 설명되며, 과제와 시험이 쉬운 편이라 학점 취득이 용이하나, 내용의 깊이는 부족하다는 의견이 있습니다. 반면, 다른 교수님의 강의는 소통 부족과 강의 자료의 질이 낮아 비판을 받고 있으며, 학습 효과가 적다는 평가가 많습니다.| good | 551	 반도체소자및설계 	 | 반도체소자및설계 강의는 박재우 교수님의 강의력에 대한 긍정적인 평가가 많지만, 성적 산출에 대한 아쉬움이 존재합니다. 강의는 기초부터 자세히 설명되며, 과제와 시험이 쉬운 편이라 학점 취득이 용이하나, 내용의 깊이는 부족하다는 의견이...
# | time | lectureID: 551, elapsed time: 2.86 seconds |
# |      |
# | info | in 반도체소자및설계 - 552
# 반도체소자및설계 강의는 교수님의 강의력이 좋고 열정적이나, 수업 내용이 다소 난잡하고 빠르게 진행되어 복습이 필요하다는 평가가 많습니다. 퀴즈와 시험에서 암기력이 중요하며, 성적은 후하게 주는 편입니다. 과제는 차세대 메모리 조사로 부담이 적고, 강의 자료를 잘 활용하면 좋은 성적을 받을 수 있습니다.| good | 552	 반도체소자및설계 	 | 반도체소자및설계 강의는 교수님의 강의력이 좋고 열정적이나, 수업 내용이 다소 난잡하고 빠르게 진행되어 복습이 필요하다는 평가가 많습니다. 퀴즈와 시험에서 암기력이 중요하며, 성적은 후하게 주는 편입니다. 과제는 차세대 메모리 조사로 ...
# | time | lectureID: 552, elapsed time: 2.34 seconds |
# |      |
# | info | in 반도체소자및설계 - 553
# 반도체소자및설계 강의는 박하민 교수님의 뛰어난 강의력과 질문에 대한 친절한 응답이 특징입니다. 시험은 어려운 편이며, 단순 암기보다는 이해를 바탕으로 한 응용이 중요합니다. 과제와 퀴즈는 상대적으로 쉬운 편이나, 성적을 잘 받기 위해서는 성실한 공부가 필요합니다.| good | 553	 반도체소자및설계 	 | 반도체소자및설계 강의는 박하민 교수님의 뛰어난 강의력과 질문에 대한 친절한 응답이 특징입니다. 시험은 어려운 편이며, 단순 암기보다는 이해를 바탕으로 한 응용이 중요합니다. 과제와 퀴즈는 상대적으로 쉬운 편이나, 성적을 잘 받기 위해...
# | time | lectureID: 553, elapsed time: 1.75 seconds |
# |      |
# | info | in 광전자공학 - 554
# 광전자공학 강의는 교수님의 친절한 설명과 강조된 내용 위주로 공부하면 좋은 성적을 받을 수 있다는 평가가 많습니다. 시험은 영어로 객관식 및 단답형으로 출제되며, 팀 프로젝트와 과제가 있지만 큰 부담은 없다고 합니다. 수업 내용은 다소 어려울 수 있으나, 열심히 준비하면 충분히 이해할 수 있는 강의입니다.| good | 554	 광전자공학 	 | 광전자공학 강의는 교수님의 친절한 설명과 강조된 내용 위주로 공부하면 좋은 성적을 받을 수 있다는 평가가 많습니다. 시험은 영어로 객관식 및 단답형으로 출제되며, 팀 프로젝트와 과제가 있지만 큰 부담은 없다고 합니다. 수업 내용은 다...
# | time | lectureID: 554, elapsed time: 4.05 seconds |
# |      |
# | info | in 광통신공학 - 555
# 광통신공학 강의는 교수님의 전달력이 부족하고 과제가 많지만, 기출문제를 활용하면 성적을 잘 받을 수 있는 과목입니다. 수업 내용은 어렵지 않으나 혼자 공부해야 하며, 절대평가와 상대평가에 따라 성적 차이가 클 수 있습니다. 전반적으로 암기 위주의 학습이 필요하며, 교수님은 친절하다는 평가가 있습니다.| good | 555	 광통신공학 	 | 광통신공학 강의는 교수님의 전달력이 부족하고 과제가 많지만, 기출문제를 활용하면 성적을 잘 받을 수 있는 과목입니다. 수업 내용은 어렵지 않으나 혼자 공부해야 하며, 절대평가와 상대평가에 따라 성적 차이가 클 수 있습니다. 전반적으로...
# | time | lectureID: 555, elapsed time: 2.42 seconds |
# |      |
# | info | in 이동통신시스템 - 556
# 이동통신시스템 강의는 온라인 강의와 대면 강의가 혼합된 형태로 진행되며, 교수님이 친절하고 강의의 질이 우수하다는 평가를 받고 있습니다. 시험은 객관식과 주관식 문제로 구성되며, 성적 부담이 적고 통신 시스템의 흐름을 배우는 교양적인 느낌이 강합니다. 질문을 통해 얻는 것이 많지만, 수업 참여가 중요합니다.| good | 556	 이동통신시스템 	 | 이동통신시스템 강의는 온라인 강의와 대면 강의가 혼합된 형태로 진행되며, 교수님이 친절하고 강의의 질이 우수하다는 평가를 받고 있습니다. 시험은 객관식과 주관식 문제로 구성되며, 성적 부담이 적고 통신 시스템의 흐름을 배우는 교양적인...
# | time | lectureID: 556, elapsed time: 2.43 seconds |
# |      |
# | info | in 정보이론 - 557
# 정보이론 강의는 절대평가로 성적이 잘 주어지며, 강의 내용은 다소 어려울 수 있지만 교수님이 친절하게 설명해주고 예제 문제를 통해 이해를 돕습니다. 기말 시험에서 치팅 페이퍼를 허용하므로, 열심히 준비하면 A+를 받을 수 있는 기회가 많습니다. 전반적으로 학점 부담이 적고, 강의 자료가 잘 구성되어 있어 혼자서 공부하기 좋은 환경입니다.| good | 557	 정보이론 	 | 정보이론 강의는 절대평가로 성적이 잘 주어지며, 강의 내용은 다소 어려울 수 있지만 교수님이 친절하게 설명해주고 예제 문제를 통해 이해를 돕습니다. 기말 시험에서 치팅 페이퍼를 허용하므로, 열심히 준비하면 A+를 받을 수 있는 기회가...
# | time | lectureID: 557, elapsed time: 2.28 seconds |
# |      |
# | info | in 인공지능과음성신호처리 - 558
# 교수님의 강의력이 뛰어나고, 절대평가로 성적이 후하게 주어지는 편입니다. C언어 과제가 있으며, 과제는 교수님이 많은 도움을 주어 비교적 쉽게 해결할 수 있습니다. 시험 난이도는 다소 높지만, 강의를 잘 듣고 이해하면 좋은 성적을 받을 수 있습니다.| good | 558	 인공지능과음성신호처리 	 | 교수님의 강의력이 뛰어나고, 절대평가로 성적이 후하게 주어지는 편입니다. C언어 과제가 있으며, 과제는 교수님이 많은 도움을 주어 비교적 쉽게 해결할 수 있습니다. 시험 난이도는 다소 높지만, 강의를 잘 듣고 이해하면 좋은 성적을 받...
# | time | lectureID: 558, elapsed time: 1.67 seconds |
# |      |
# | info | in 캡스톤설계 - 559
# 캡스톤설계 강의는 학점이 깐깐하게 주며, 팀원과 교수님과의 조율이 중요합니다. 방학 전에 미리 주제를 정하고 준비하는 것이 추천되며, 학기 중에는 시간이 부족할 수 있습니다. 좋은 팀원과 교수님을 잘 선택하는 것이 성공의 열쇠입니다.| good | 559	 캡스톤설계 	 | 캡스톤설계 강의는 학점이 깐깐하게 주며, 팀원과 교수님과의 조율이 중요합니다. 방학 전에 미리 주제를 정하고 준비하는 것이 추천되며, 학기 중에는 시간이 부족할 수 있습니다. 좋은 팀원과 교수님을 잘 선택하는 것이 성공의 열쇠입니다.
# | time | lectureID: 559, elapsed time: 2.57 seconds |
# |      |
# | info | in RF시스템 - 560
# RF시스템 강의는 교수님이 강조하는 내용 위주로 시험이 출제되어 쉽게 A+를 받을 수 있는 수업입니다. 부담 없이 들을 수 있는 전공 과목으로, 실무와 연계된 내용이 많아 흥미롭고 유익하다는 평가가 있습니다. 다만, 시험에서 실수를 하면 성적에 큰 영향을 미칠 수 있으니 주의가 필요합니다.| good | 560	 RF시스템 	 | RF시스템 강의는 교수님이 강조하는 내용 위주로 시험이 출제되어 쉽게 A+를 받을 수 있는 수업입니다. 부담 없이 들을 수 있는 전공 과목으로, 실무와 연계된 내용이 많아 흥미롭고 유익하다는 평가가 있습니다. 다만, 시험에서 실수를 ...
# | time | lectureID: 560, elapsed time: 2.24 seconds |
# |      |
# | info | in 임베디드시스템 - 561
# 임베디드시스템 강의는 절대평가로 진행되며, C언어와 MIPS 어셈블리어를 기반으로 한 과목입니다. 교수님의 강의력은 부족하고, 수업 내용 전달이 미흡하지만, 과제는 간단하며 시험은 ppt 자료 위주로 쉽게 출제됩니다. 프로그램 설계보다는 해석과 분석에 중점을 두고 있어 실질적인 응용 능력에는 한계가 있을 수 있습니다.| good | 561	 임베디드시스템 	 | 임베디드시스템 강의는 절대평가로 진행되며, C언어와 MIPS 어셈블리어를 기반으로 한 과목입니다. 교수님의 강의력은 부족하고, 수업 내용 전달이 미흡하지만, 과제는 간단하며 시험은 ppt 자료 위주로 쉽게 출제됩니다. 프로그램 설계보...
# | time | lectureID: 561, elapsed time: 1.95 seconds |
# |      |
# | pass | 562 | len(reviews) < 3
# | info | in 디지털공학 - 563
# 디지털공학 강의는 교수님의 열정적인 강의와 좋은 강의력에도 불구하고, 진도가 매우 빠르고 과제가 많아 학생들이 따라가기 힘들다는 평가가 많습니다. 시험은 기출문제를 중심으로 출제되며, 과제를 잘 수행하면 좋은 성적을 받을 수 있지만, 랩 과제가 특히 어렵고 스트레스를 유발하는 요소로 지적되고 있습니다.| good | 563	 디지털공학 	 | 디지털공학 강의는 교수님의 열정적인 강의와 좋은 강의력에도 불구하고, 진도가 매우 빠르고 과제가 많아 학생들이 따라가기 힘들다는 평가가 많습니다. 시험은 기출문제를 중심으로 출제되며, 과제를 잘 수행하면 좋은 성적을 받을 수 있지만,...
# | time | lectureID: 563, elapsed time: 5.09 seconds |
# |      |
# | info | in 디지털공학 - 564
# 디지털공학 강의는 교수님의 열정적인 강의와 좋은 강의력에도 불구하고, 진도가 매우 빠르고 과제가 많아 학생들이 따라가기 힘들다는 평가가 많습니다. 시험은 기출문제를 중심으로 출제되며, 과제를 잘 수행하면 좋은 성적을 받을 수 있지만, 랩 과제가 특히 어렵고 스트레스를 유발하는 요소로 지적되고 있습니다.| good | 564	 디지털공학 	 | 디지털공학 강의는 교수님의 열정적인 강의와 좋은 강의력에도 불구하고, 진도가 매우 빠르고 과제가 많아 학생들이 따라가기 힘들다는 평가가 많습니다. 시험은 기출문제를 중심으로 출제되며, 과제를 잘 수행하면 좋은 성적을 받을 수 있지만,...
# | time | lectureID: 564, elapsed time: 2.09 seconds |
# |      |
# | info | in 물리전자 - 565
# 물리전자 강의는 교수님의 강의력이 좋고 자료 준비에 열정적이나, 목소리가 작고 수업이 이론 중심으로 진행되어 집중이 필요합니다. 과제와 시험이 밀접하게 연관되어 있어 과제를 잘 풀면 좋은 성적을 받을 수 있지만, 과제가 어려워서 많은 학생들이 힘들어합니다. 반도체에 관심이 없는 학생에게는 도전적일 수 있습니다.| good | 565	 물리전자 	 | 물리전자 강의는 교수님의 강의력이 좋고 자료 준비에 열정적이나, 목소리가 작고 수업이 이론 중심으로 진행되어 집중이 필요합니다. 과제와 시험이 밀접하게 연관되어 있어 과제를 잘 풀면 좋은 성적을 받을 수 있지만, 과제가 어려워서 많은...
# | time | lectureID: 565, elapsed time: 2.12 seconds |
# |      |
# | info | in 물리전자 - 566
# 물리전자 강의는 교수님의 강의력이 좋고, 설명이 자세하지만 과목 자체가 매우 어려워 학생들이 이해하기 힘들다는 평가가 많습니다. 과제는 어렵고 시험은 교수님이 다룬 내용에서 출제되며, 많은 학생들이 포기하지만 그로 인해 상대적으로 학점은 잘 나오는 편입니다. 수업 녹화로 복습이 가능해 성실히 수강하면 좋은 성적을 받을 수 있습니다.| good | 566	 물리전자 	 | 물리전자 강의는 교수님의 강의력이 좋고, 설명이 자세하지만 과목 자체가 매우 어려워 학생들이 이해하기 힘들다는 평가가 많습니다. 과제는 어렵고 시험은 교수님이 다룬 내용에서 출제되며, 많은 학생들이 포기하지만 그로 인해 상대적으로 학...
# | time | lectureID: 566, elapsed time: 1.99 seconds |
# |      |
# | info | in 전자기학1 - 567
# 전자기학1 강의는 교수님이 개념을 쉽게 설명해주고, 시험 문제는 주로 예제와 과제에서 출제됩니다. 과제가 적고, 예제를 반복적으로 풀면 좋은 성적을 받을 수 있지만, 과목 자체가 어려워 암기력이 중요합니다. 교수님의 강의력은 좋지만, 전반적으로 학생들이 힘들어하는 과목입니다.| good | 567	 전자기학1 	 | 전자기학1 강의는 교수님이 개념을 쉽게 설명해주고, 시험 문제는 주로 예제와 과제에서 출제됩니다. 과제가 적고, 예제를 반복적으로 풀면 좋은 성적을 받을 수 있지만, 과목 자체가 어려워 암기력이 중요합니다. 교수님의 강의력은 좋지만,...
# | time | lectureID: 567, elapsed time: 1.70 seconds |
# |      |
# | info | in 전자기학1 - 568
# 전자기학1 강의는 교수님이 개념을 쉽게 설명해주고, 시험 문제는 주로 예제와 과제에서 출제됩니다. 과제가 적고, 예제를 반복적으로 풀면 좋은 성적을 받을 수 있지만, 과목 자체가 어려워 암기력이 중요합니다. 교수님의 강의력은 좋으나, 전반적으로 학생들이 힘들어하는 과목입니다.| good | 568	 전자기학1 	 | 전자기학1 강의는 교수님이 개념을 쉽게 설명해주고, 시험 문제는 주로 예제와 과제에서 출제됩니다. 과제가 적고, 예제를 반복적으로 풀면 좋은 성적을 받을 수 있지만, 과목 자체가 어려워 암기력이 중요합니다. 교수님의 강의력은 좋으나,...
# | time | lectureID: 568, elapsed time: 3.78 seconds |
# |      |
# | info | in 회로이론1 - 569
# 회로이론1 강의는 출석이 널널하고, 교수님의 강의력은 좋지만 설명이 다소 두서없어 이해하기 어려울 수 있습니다. 시험은 중간과 기말에 각각 2~3문제가 출제되며, 개념 위주의 문제가 많아 기본 개념을 잘 숙지하면 좋은 성적을 받을 수 있습니다. 복습 영상이 제공되어 학습에 도움이 되며, 과제는 부담이 적습니다.| good | 569	 회로이론1 	 | 회로이론1 강의는 출석이 널널하고, 교수님의 강의력은 좋지만 설명이 다소 두서없어 이해하기 어려울 수 있습니다. 시험은 중간과 기말에 각각 2~3문제가 출제되며, 개념 위주의 문제가 많아 기본 개념을 잘 숙지하면 좋은 성적을 받을 수...
# | time | lectureID: 569, elapsed time: 2.02 seconds |
# |      |
# | info | in 기초전자회로실험1 - 570
# 기초전자회로실험1 강의는 스스로 학습해야 하는 부담이 크고, 레포트와 발표가 많아 힘든 수업입니다. 교수님은 친절하지만 실험 준비와 발표에 많은 시간을 투자해야 하며, 성적은 실험 능력에 따라 결정됩니다. 열심히 하면 많은 것을 배울 수 있지만, 준비가 부족하면 어려움을 겪을 수 있습니다.| good | 570	 기초전자회로실험1 	 | 기초전자회로실험1 강의는 스스로 학습해야 하는 부담이 크고, 레포트와 발표가 많아 힘든 수업입니다. 교수님은 친절하지만 실험 준비와 발표에 많은 시간을 투자해야 하며, 성적은 실험 능력에 따라 결정됩니다. 열심히 하면 많은 것을 배울...
# | time | lectureID: 570, elapsed time: 1.63 seconds |
# |      |
# | info | in 기초전자회로실험1 - 571
# 기초전자회로실험1 강의는 성적이 잘 주고, 레포트 제출이 팀당 하나로 간편해 매우 수월하다는 긍정적인 평가가 많습니다. 교수님은 프로젝트 발표 때만 보이며, 전반적으로 시간 절약과 편리함이 강조됩니다. 이 강의를 꼭 수강하라는 추천이 이어집니다.| good | 571	 기초전자회로실험1 	 | 기초전자회로실험1 강의는 성적이 잘 주고, 레포트 제출이 팀당 하나로 간편해 매우 수월하다는 긍정적인 평가가 많습니다. 교수님은 프로젝트 발표 때만 보이며, 전반적으로 시간 절약과 편리함이 강조됩니다. 이 강의를 꼭 수강하라는 추천이...
# | time | lectureID: 571, elapsed time: 1.55 seconds |
# |      |
# | info | in 기초전자회로실험1 - 572
# 기초전자회로실험1 강의는 2인 1조로 진행되며, 매주 발표와 프로젝트가 있어 시간과 노력이 많이 소요됩니다. 조교의 영향력이 크고, 성적은 노력에 비례하여 잘 주어지는 편입니다. 실험과 발표를 통해 실력 향상에 도움이 되지만, 과제가 많아 바쁠 수 있습니다.| good | 572	 기초전자회로실험1 	 | 기초전자회로실험1 강의는 2인 1조로 진행되며, 매주 발표와 프로젝트가 있어 시간과 노력이 많이 소요됩니다. 조교의 영향력이 크고, 성적은 노력에 비례하여 잘 주어지는 편입니다. 실험과 발표를 통해 실력 향상에 도움이 되지만, 과제가...
# | time | lectureID: 572, elapsed time: 1.50 seconds |
# |      |
# | info | in 디지털신호처리 - 573
# 디지털신호처리 강의는 교수님의 강의력이 좋고, 필기가 많지만 이해하기 쉽게 설명해주며, 과제와 시험 난이도는 적당하다는 평가가 많습니다. 수학적인 내용이 많고, 족보나 예제 문제 풀이가 중요하며, 진도가 느리다는 아쉬움도 있습니다. 전반적으로 수업 내용은 유익하지만, 수학에 대한 자신감이 필요합니다.| good | 573	 디지털신호처리 	 | 디지털신호처리 강의는 교수님의 강의력이 좋고, 필기가 많지만 이해하기 쉽게 설명해주며, 과제와 시험 난이도는 적당하다는 평가가 많습니다. 수학적인 내용이 많고, 족보나 예제 문제 풀이가 중요하며, 진도가 느리다는 아쉬움도 있습니다. ...
# | time | lectureID: 573, elapsed time: 1.58 seconds |
# |      |
# | info | in 시스템프로그래밍 - 574
# 시스템프로그래밍 강의는 교수님의 상세한 설명 덕분에 코딩 경험이 부족한 학생도 A+를 받을 수 있는 기회가 많습니다. 강의 내용이 방대하지만, 반복적인 설명과 쉬운 시험 덕분에 이해하기 쉽고 유익하다는 평가가 있습니다. 다만, PPT 내용이 줄글로 되어 있어 졸릴 수 있다는 점은 아쉬움으로 지적됩니다.| good | 574	 시스템프로그래밍 	 | 시스템프로그래밍 강의는 교수님의 상세한 설명 덕분에 코딩 경험이 부족한 학생도 A+를 받을 수 있는 기회가 많습니다. 강의 내용이 방대하지만, 반복적인 설명과 쉬운 시험 덕분에 이해하기 쉽고 유익하다는 평가가 있습니다. 다만, PPT...
# | time | lectureID: 574, elapsed time: 1.53 seconds |
# |      |
# | pass | 575 | len(reviews) < 3
# | info | in 전자회로1 - 576
# 전자회로1 강의는 교수님의 강의력이 뛰어나고, 설명이 깔끔하다는 평가가 많습니다. 그러나 진도가 매우 빠르며, 과제와 시험 준비를 위해 많은 문제를 풀어야 합니다. 시험은 교재 문제와 연습문제를 기반으로 하며, 채점이 엄격하므로 철저한 준비가 필요합니다.| good | 576	 전자회로1 	 | 전자회로1 강의는 교수님의 강의력이 뛰어나고, 설명이 깔끔하다는 평가가 많습니다. 그러나 진도가 매우 빠르며, 과제와 시험 준비를 위해 많은 문제를 풀어야 합니다. 시험은 교재 문제와 연습문제를 기반으로 하며, 채점이 엄격하므로 철저...
# | time | lectureID: 576, elapsed time: 1.28 seconds |
# |      |
# | info | in 전자회로1 - 577
# 전자회로1 강의는 교수님의 강의력이 뛰어나고 설명이 깔끔하다는 평가가 많지만, 진도가 매우 빠르기 때문에 복습이 필수적입니다. 과제와 퀴즈는 적당하며, 시험은 교재 문제와 연습문제를 충분히 풀어야 좋은 성적을 받을 수 있습니다. 시험 채점은 엄격하므로 실수에 주의해야 합니다.| good | 577	 전자회로1 	 | 전자회로1 강의는 교수님의 강의력이 뛰어나고 설명이 깔끔하다는 평가가 많지만, 진도가 매우 빠르기 때문에 복습이 필수적입니다. 과제와 퀴즈는 적당하며, 시험은 교재 문제와 연습문제를 충분히 풀어야 좋은 성적을 받을 수 있습니다. 시험...
# | time | lectureID: 577, elapsed time: 1.50 seconds |
# |      |
# | info | in 전자회로실험1 - 578
# 전자회로실험1 강의는 예비 보고서가 없어 부담이 적고, 교수님의 이론 강의가 도움이 된다는 긍정적인 평가가 많습니다. 시험은 공부를 조금만 하면 무난히 통과할 수 있지만, 시험 준비가 중요하다는 의견도 있습니다.| good | 578	 전자회로실험1 	 | 전자회로실험1 강의는 예비 보고서가 없어 부담이 적고, 교수님의 이론 강의가 도움이 된다는 긍정적인 평가가 많습니다. 시험은 공부를 조금만 하면 무난히 통과할 수 있지만, 시험 준비가 중요하다는 의견도 있습니다.
# | time | lectureID: 578, elapsed time: 1.51 seconds |
# |      |
# | pass | 579 | len(reviews) < 3
# | info | in 전자회로실험1 - 580
# 전자회로실험1 강의는 교수님이 너그럽고 유머가 있으며, 실험과 시험이 무난하게 진행됩니다. 열심히 참여하면 좋은 성적을 받을 수 있고, 부담 없이 수업을 진행할 수 있다는 긍정적인 평가가 많습니다.| good | 580	 전자회로실험1 	 | 전자회로실험1 강의는 교수님이 너그럽고 유머가 있으며, 실험과 시험이 무난하게 진행됩니다. 열심히 참여하면 좋은 성적을 받을 수 있고, 부담 없이 수업을 진행할 수 있다는 긍정적인 평가가 많습니다.
# | time | lectureID: 580, elapsed time: 1.18 seconds |
# |      |
# | info | in 전자회로실험1 - 581
# 전자회로실험1 강의는 교수님이 매우 훌륭하고 학점도 잘 주며, 수강할 가치가 높다는 긍정적인 평가가 많습니다. 반드시 들어야 할 강의로 추천됩니다.| good | 581	 전자회로실험1 	 | 전자회로실험1 강의는 교수님이 매우 훌륭하고 학점도 잘 주며, 수강할 가치가 높다는 긍정적인 평가가 많습니다. 반드시 들어야 할 강의로 추천됩니다.
# | time | lectureID: 581, elapsed time: 1.00 seconds |
# |      |
# | info | in 컴퓨터구조 - 582
# 컴퓨터구조 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이며, 과제와 랩이 다소 어렵지만 유익하다는 평가가 많습니다. 시험은 기출문제와 족보에 의존하는 경향이 있으며, 성적은 노력한 만큼 잘 주어지는 편입니다. 다만, 수업 내용을 따라가기 위해서는 충분한 복습과 준비가 필요합니다.| good | 582	 컴퓨터구조 	 | 컴퓨터구조 강의는 교수님의 열정적인 강의와 친절한 설명이 돋보이며, 과제와 랩이 다소 어렵지만 유익하다는 평가가 많습니다. 시험은 기출문제와 족보에 의존하는 경향이 있으며, 성적은 노력한 만큼 잘 주어지는 편입니다. 다만, 수업 내용...
# | time | lectureID: 582, elapsed time: 1.56 seconds |
# |      |
# | info | in 통신이론 - 583
# 통신이론 강의는 교수님의 강의력이 엇갈린 평가를 받고 있으며, 일부 학생들은 열정적이고 이해하기 쉽게 설명한다고 느끼는 반면, 다른 학생들은 강의 준비 부족과 이해하기 어려운 수업 진행에 불만을 표하고 있습니다. 과제는 수월하나, 시험 난이도는 높아 사전 지식이 필요하다는 의견이 많습니다. 전반적으로 강의의 질이 낮다는 평가가 있으며, 성적은 상대적으로 잘 주는 편입니다.| good | 583	 통신이론 	 | 통신이론 강의는 교수님의 강의력이 엇갈린 평가를 받고 있으며, 일부 학생들은 열정적이고 이해하기 쉽게 설명한다고 느끼는 반면, 다른 학생들은 강의 준비 부족과 이해하기 어려운 수업 진행에 불만을 표하고 있습니다. 과제는 수월하나, 시...
# | time | lectureID: 583, elapsed time: 1.80 seconds |
# |      |
# | info | in 광전자공학 - 584
# 광전자공학 강의는 교수님의 친절한 설명과 과거 시험문제를 활용한 학습이 큰 도움이 되며, 절대평가로 성적이 너그럽게 주어집니다. 과제와 퀴즈가 적당히 주어져 무난하게 수업을 따라갈 수 있으며, 주요 내용은 광통신에 집중되어 있습니다. 전반적으로 추천할 만한 수업입니다.| good | 584	 광전자공학 	 | 광전자공학 강의는 교수님의 친절한 설명과 과거 시험문제를 활용한 학습이 큰 도움이 되며, 절대평가로 성적이 너그럽게 주어집니다. 과제와 퀴즈가 적당히 주어져 무난하게 수업을 따라갈 수 있으며, 주요 내용은 광통신에 집중되어 있습니다....
# | time | lectureID: 584, elapsed time: 1.46 seconds |
# |      |
# | info | in 네트워크프로그래밍 - 585
# 네트워크프로그래밍 강의는 교수님이 학생 편의를 많이 고려하며, 중간고사가 없고 과제가 적어 학점 취득이 용이하다는 평가가 많습니다. 소켓 프로그래밍을 배우고 싶다면 추천할 만하며, 수업에 집중하면 이해가 잘 간다는 의견이 있습니다. 다만, 초반 내용이 다소 아쉽다는 피드백도 있습니다.| good | 585	 네트워크프로그래밍 	 | 네트워크프로그래밍 강의는 교수님이 학생 편의를 많이 고려하며, 중간고사가 없고 과제가 적어 학점 취득이 용이하다는 평가가 많습니다. 소켓 프로그래밍을 배우고 싶다면 추천할 만하며, 수업에 집중하면 이해가 잘 간다는 의견이 있습니다. ...
# | time | lectureID: 585, elapsed time: 1.70 seconds |
# |      |
# | info | in 네트워크프로그래밍 - 586
# 네트워크프로그래밍 강의는 교수님이 학생 편의를 많이 고려하며, 중간고사가 없고 과제가 적어 학점 취득이 용이하다는 평가가 많습니다. 소켓 프로그래밍을 배우고 싶다면 추천할 만하며, 수업에 집중하면 이해가 잘 간다는 의견이 있습니다. 다만, 초반 내용이 다소 아쉬운 부분도 언급되고 있습니다.| good | 586	 네트워크프로그래밍 	 | 네트워크프로그래밍 강의는 교수님이 학생 편의를 많이 고려하며, 중간고사가 없고 과제가 적어 학점 취득이 용이하다는 평가가 많습니다. 소켓 프로그래밍을 배우고 싶다면 추천할 만하며, 수업에 집중하면 이해가 잘 간다는 의견이 있습니다. ...
# | time | lectureID: 586, elapsed time: 1.37 seconds |
# |      |
# | pass | 587 | len(reviews) < 3
# | info | in 기초회로실험1 - 588
# 기초회로실험1 강의는 프로젝트 중심으로 진행되며, 조교님이 매우 친절하고 학점이 잘 주어지는 편입니다. 중간고사는 프로젝트로 대체되며, 기말고사는 쉬운 편이지만 지엽적인 문제가 출제될 수 있습니다. 레포트는 양식만 지키면 점수가 보장되며, 프로젝트의 완성도가 중요합니다.| good | 588	 기초회로실험1 	 | 기초회로실험1 강의는 프로젝트 중심으로 진행되며, 조교님이 매우 친절하고 학점이 잘 주어지는 편입니다. 중간고사는 프로젝트로 대체되며, 기말고사는 쉬운 편이지만 지엽적인 문제가 출제될 수 있습니다. 레포트는 양식만 지키면 점수가 보장...
# | time | lectureID: 588, elapsed time: 1.63 seconds |
# |      |
# | info | in 기초회로실험1 - 589
# 기초회로실험1 강의는 프로젝트의 작동 여부가 중요하며, 시험은 상대적으로 쉬운 편입니다. 조교들이 친절하여 수업 분위기가 좋고, 절대평가로 점수가 후하게 주어지는 경향이 있습니다. 팀 프로젝트와 시험 준비를 잘하면 높은 성적을 받을 수 있습니다.| good | 589	 기초회로실험1 	 | 기초회로실험1 강의는 프로젝트의 작동 여부가 중요하며, 시험은 상대적으로 쉬운 편입니다. 조교들이 친절하여 수업 분위기가 좋고, 절대평가로 점수가 후하게 주어지는 경향이 있습니다. 팀 프로젝트와 시험 준비를 잘하면 높은 성적을 받을 ...
# | time | lectureID: 589, elapsed time: 1.36 seconds |
# |      |
# | info | in 디지털공학 - 590
# 디지털공학 강의는 교수님의 강의력이 좋고, 수업 중 복습이 이루어져 이해를 돕지만, 진도가 빠르고 내용이 어려워 복습이 필요합니다. 과제는 챕터마다 있으며, 베릴로그 과제가 특히 어렵지만, 과제를 잘 수행하면 시험에서 좋은 성적을 받을 수 있습니다. 시험은 과제와 유사한 문제로 출제되며, 학생들에게 친절하게 질문을 받아주는 분위기입니다.| good | 590	 디지털공학 	 | 디지털공학 강의는 교수님의 강의력이 좋고, 수업 중 복습이 이루어져 이해를 돕지만, 진도가 빠르고 내용이 어려워 복습이 필요합니다. 과제는 챕터마다 있으며, 베릴로그 과제가 특히 어렵지만, 과제를 잘 수행하면 시험에서 좋은 성적을 받...
# | time | lectureID: 590, elapsed time: 1.79 seconds |
# |      |
# | info | in 디지털공학 - 591
# 디지털공학 강의는 교수님의 강의력이 좋고, 수업 중 개념 설명이 잘 이루어지지만 진도가 빠르고 과제가 많아 복습이 필요합니다. 시험은 과제와 유사한 문제로 출제되며, 스스로 과제를 잘 풀면 좋은 성적을 받을 수 있습니다. 과목이 어려운 편이지만 교수님의 친절한 설명 덕분에 이해하는 데 도움이 됩니다.| good | 591	 디지털공학 	 | 디지털공학 강의는 교수님의 강의력이 좋고, 수업 중 개념 설명이 잘 이루어지지만 진도가 빠르고 과제가 많아 복습이 필요합니다. 시험은 과제와 유사한 문제로 출제되며, 스스로 과제를 잘 풀면 좋은 성적을 받을 수 있습니다. 과목이 어려...
# | time | lectureID: 591, elapsed time: 2.37 seconds |
# |      |
# | info | in 전자기학1 - 592
# 전자기학1 강의는 교수님의 강의력이 좋지만 과목 자체가 어려워 학생들이 힘들어하는 경향이 있습니다. 오픈북 시험이지만 족보와 과제를 철저히 준비해야 좋은 성적을 받을 수 있으며, 과제가 매주 주어지는 등 학습 부담이 큽니다. 교수님은 질문을 잘 받아주시고, 복습을 통해 이해도를 높일 수 있는 기회를 제공합니다.| good | 592	 전자기학1 	 | 전자기학1 강의는 교수님의 강의력이 좋지만 과목 자체가 어려워 학생들이 힘들어하는 경향이 있습니다. 오픈북 시험이지만 족보와 과제를 철저히 준비해야 좋은 성적을 받을 수 있으며, 과제가 매주 주어지는 등 학습 부담이 큽니다. 교수님은...
# | time | lectureID: 592, elapsed time: 1.83 seconds |
# |      |
# | info | in 회로이론1 - 593
# 회로이론1 강의는 교수님의 강의력이 좋고 문제 풀이 위주로 진행되지만, 과제가 매우 많아 부담이 크다는 평가가 많습니다. 과제를 충실히 수행하면 시험 준비가 되며 좋은 성적을 받을 수 있지만, 과제를 미루면 따라가기 어려울 수 있습니다. 전반적으로 꾸준한 학습이 필요한 강의입니다.| good | 593	 회로이론1 	 | 회로이론1 강의는 교수님의 강의력이 좋고 문제 풀이 위주로 진행되지만, 과제가 매우 많아 부담이 크다는 평가가 많습니다. 과제를 충실히 수행하면 시험 준비가 되며 좋은 성적을 받을 수 있지만, 과제를 미루면 따라가기 어려울 수 있습니...
# | time | lectureID: 593, elapsed time: 1.68 seconds |
# |      |
# | info | in 회로이론1 - 594
# 회로이론1 강의는 교수님의 강의력이 좋고 문제 풀이 위주로 진행되지만, 과제가 매우 많아 부담이 크다는 평가가 많습니다. 과제를 성실히 수행하면 시험 준비가 되며 좋은 성적을 받을 수 있지만, 과제를 놓치면 따라가기 어려운 점이 강조됩니다.| good | 594	 회로이론1 	 | 회로이론1 강의는 교수님의 강의력이 좋고 문제 풀이 위주로 진행되지만, 과제가 매우 많아 부담이 크다는 평가가 많습니다. 과제를 성실히 수행하면 시험 준비가 되며 좋은 성적을 받을 수 있지만, 과제를 놓치면 따라가기 어려운 점이 강조...
# | time | lectureID: 594, elapsed time: 1.47 seconds |
# |      |
# | info | in 반도체소자1 - 595
# 반도체소자1 강의는 교수님의 강의력이 부족하고, 과제가 많아 귀찮다는 평가가 많습니다. 시험은 족보에 의존하며, 독학이 필수적이라는 의견이 지배적입니다. 교수님은 친절하지만, 수업 내용에서 얻는 것이 적다는 비판이 있습니다.| good | 595	 반도체소자1 	 | 반도체소자1 강의는 교수님의 강의력이 부족하고, 과제가 많아 귀찮다는 평가가 많습니다. 시험은 족보에 의존하며, 독학이 필수적이라는 의견이 지배적입니다. 교수님은 친절하지만, 수업 내용에서 얻는 것이 적다는 비판이 있습니다.
# | time | lectureID: 595, elapsed time: 1.42 seconds |
# |      |
# | info | in 반도체소자1 - 596
# 반도체소자1 강의는 교수님의 강의력이 부족하고, 과제가 많아 귀찮다는 평가가 많습니다. 시험은 족보에 의존하며, 독학이 필수적이라는 의견이 지배적입니다. 전반적으로 얻는 것이 적고 비효율적인 수업으로, 다른 과목을 듣는 것이 더 나은 선택이라는 추천이 많습니다.| good | 596	 반도체소자1 	 | 반도체소자1 강의는 교수님의 강의력이 부족하고, 과제가 많아 귀찮다는 평가가 많습니다. 시험은 족보에 의존하며, 독학이 필수적이라는 의견이 지배적입니다. 전반적으로 얻는 것이 적고 비효율적인 수업으로, 다른 과목을 듣는 것이 더 나은...
# | time | lectureID: 596, elapsed time: 1.66 seconds |
# |      |
# | pass | 598 | len(reviews) < 3
# | info | in 전자회로실험1 - 599
# 전자회로실험1 강의는 교수님과 조교님의 친절한 지원과 실험 내용에 대한 명확한 설명이 긍정적으로 평가되며, 시험 난이도는 적당하나 레포트와 시작 시간이 빡빡하다는 의견이 있습니다. 전반적으로 실험을 통해 성장할 수 있는 유익한 경험으로, 교수님의 답변 퀄리티가 높고 직접 장비 사용법을 잘 알려줍니다.| good | 599	 전자회로실험1 	 | 전자회로실험1 강의는 교수님과 조교님의 친절한 지원과 실험 내용에 대한 명확한 설명이 긍정적으로 평가되며, 시험 난이도는 적당하나 레포트와 시작 시간이 빡빡하다는 의견이 있습니다. 전반적으로 실험을 통해 성장할 수 있는 유익한 경험으...
# | time | lectureID: 599, elapsed time: 1.42 seconds |
# |      |
# | pass | 600 | len(reviews) < 3
# | info | in 영상신호처리 - 601
# 영상신호처리 강의는 불친절한 수업 진행과 많은 레포트 과제가 특징이며, 스스로 공부해야 할 부분이 많습니다. 절대평가로 진행되지만, 실습과 C++ 기초를 배우는 데는 유익할 수 있습니다. 디지털신호처리와의 연계가 없으니, 해당 분야에 관심이 없다면 수강을 재고하는 것이 좋습니다.| good | 601	 영상신호처리 	 | 영상신호처리 강의는 불친절한 수업 진행과 많은 레포트 과제가 특징이며, 스스로 공부해야 할 부분이 많습니다. 절대평가로 진행되지만, 실습과 C++ 기초를 배우는 데는 유익할 수 있습니다. 디지털신호처리와의 연계가 없으니, 해당 분야에...
# | time | lectureID: 601, elapsed time: 1.90 seconds |
# |      |
# | pass | 602 | len(reviews) < 3
# | info | in 초고주파응용 - 603
# 초고주파응용 강의는 내용이 유익하지만 어려운 과목으로, 교수님의 강의력에 대한 의견이 엇갈립니다. 절대평가로 학점은 잘 주지만, 시험 난이도가 높아 이해가 필수적이며, 족보나 과제 준비가 중요합니다. RF 진로를 희망하는 학생에게 추천되지만, 수업에 대한 개인적인 만족도는 차이가 있습니다.| good | 603	 초고주파응용 	 | 초고주파응용 강의는 내용이 유익하지만 어려운 과목으로, 교수님의 강의력에 대한 의견이 엇갈립니다. 절대평가로 학점은 잘 주지만, 시험 난이도가 높아 이해가 필수적이며, 족보나 과제 준비가 중요합니다. RF 진로를 희망하는 학생에게 추...
# | time | lectureID: 603, elapsed time: 1.31 seconds |
# |      |
# | info | in 머신러닝 - 604
# 머신러닝 강의는 오픈북 시험으로 수업만 잘 듣고 필기하면 무난히 점수를 받을 수 있으며, 파이썬 기초 지식이 필요합니다. 강의 내용은 어려울 수 있지만, 교수님의 설명이 좋고 복습할 수 있는 자료가 제공되어 학습에 도움이 됩니다. 과제는 간단하지만 양이 많아질 경우 좋겠다는 의견도 있습니다.| good | 604	 머신러닝 	 | 머신러닝 강의는 오픈북 시험으로 수업만 잘 듣고 필기하면 무난히 점수를 받을 수 있으며, 파이썬 기초 지식이 필요합니다. 강의 내용은 어려울 수 있지만, 교수님의 설명이 좋고 복습할 수 있는 자료가 제공되어 학습에 도움이 됩니다. 과...
# | time | lectureID: 604, elapsed time: 1.69 seconds |
# |      |
# | info | in 전공미리보기(OT학기제) - 605
# 전공미리보기(OT학기제) 강의는 출석만 하면 학점을 받을 수 있는 간단한 강의로, 주로 친구들과의 친목 도모와 학과 소개가 이루어집니다. 학생회 주관의 프로그램에 참여하면 되며, 강의 내용은 전공 관련 정보보다는 행사 중심입니다.| good | 605	 전공미리보기(OT학기제) 	 | 전공미리보기(OT학기제) 강의는 출석만 하면 학점을 받을 수 있는 간단한 강의로, 주로 친구들과의 친목 도모와 학과 소개가 이루어집니다. 학생회 주관의 프로그램에 참여하면 되며, 강의 내용은 전공 관련 정보보다는 행사 중심입니다.
# | time | lectureID: 605, elapsed time: 1.20 seconds |
# |      |
# | info | in 전자기학1 - 606
# 전자기학1 강의는 교수님의 강의력이 매우 뛰어나고, 온라인 녹화 강의로 과제가 없어 부담이 적습니다. 시험은 교수님이 제공하는 예제와 출제 포인트를 중심으로 준비하면 무난히 통과할 수 있지만, 과목 자체가 어려워 꾸준한 복습이 필요합니다. 성적은 비교적 너그럽게 주어지며, 열심히 공부하면 좋은 결과를 얻을 수 있습니다.| good | 606	 전자기학1 	 | 전자기학1 강의는 교수님의 강의력이 매우 뛰어나고, 온라인 녹화 강의로 과제가 없어 부담이 적습니다. 시험은 교수님이 제공하는 예제와 출제 포인트를 중심으로 준비하면 무난히 통과할 수 있지만, 과목 자체가 어려워 꾸준한 복습이 필요합...
# | time | lectureID: 606, elapsed time: 1.58 seconds |
# |      |
# | info | in 회로이론1 - 607
# 회로이론1 강의는 학점 취득이 용이하지만, 교수님의 강의력은 부족하고 배워가는 것이 적다는 평가가 많습니다. 시험 문제는 교수님이 찝어주신 내용에서 출제되며, 독학이 필요합니다. 재수강생에게는 유리하지만, 처음 배우는 학생에게는 추천되지 않습니다.| good | 607	 회로이론1 	 | 회로이론1 강의는 학점 취득이 용이하지만, 교수님의 강의력은 부족하고 배워가는 것이 적다는 평가가 많습니다. 시험 문제는 교수님이 찝어주신 내용에서 출제되며, 독학이 필요합니다. 재수강생에게는 유리하지만, 처음 배우는 학생에게는 추천...
# | time | lectureID: 607, elapsed time: 1.37 seconds |
# |      |
# | info | in 디지털논리회로설계 - 608
# 디지털논리회로설계 강의는 교수님의 강의력이 뛰어나고, 과제는 매주 주어지며 성실히 수행하면 좋은 성적을 받을 수 있습니다. 그러나 시험 난이도가 높아 과제와는 차이가 있어 철저한 준비가 필요합니다. 초반에는 쉽지만 후반부로 갈수록 어려워지므로 꾸준한 학습이 중요합니다.| good | 608	 디지털논리회로설계 	 | 디지털논리회로설계 강의는 교수님의 강의력이 뛰어나고, 과제는 매주 주어지며 성실히 수행하면 좋은 성적을 받을 수 있습니다. 그러나 시험 난이도가 높아 과제와는 차이가 있어 철저한 준비가 필요합니다. 초반에는 쉽지만 후반부로 갈수록 어...
# | time | lectureID: 608, elapsed time: 2.61 seconds |
# |      |
# | pass | 609 | len(reviews) < 3
# | info | in 전기및디지털회로실험 - 610
# 전기및디지털회로실험 강의는 조교의 역할이 중요하며, 조교가 학생들에게 친절하고 도움을 많이 준다는 긍정적인 평가가 많습니다. 조교의 운에 따라 수업 경험이 달라질 수 있습니다.| good | 610	 전기및디지털회로실험 	 | 전기및디지털회로실험 강의는 조교의 역할이 중요하며, 조교가 학생들에게 친절하고 도움을 많이 준다는 긍정적인 평가가 많습니다. 조교의 운에 따라 수업 경험이 달라질 수 있습니다.
# | time | lectureID: 610, elapsed time: 1.12 seconds |
# |      |
# | info | in 전기및디지털회로실험 - 611
# 전기및디지털회로실험 강의는 조교님의 학생 친화적인 지원 덕분에 실험과 레포트 작성이 수월하며, 성적도 잘 나오는 편입니다. 족보가 필요하고, 기말 프로젝트와 레포트 제출이 중요하지만, 전반적으로 수업 참여와 과제를 충실히 수행하면 좋은 학점을 받을 수 있습니다.| good | 611	 전기및디지털회로실험 	 | 전기및디지털회로실험 강의는 조교님의 학생 친화적인 지원 덕분에 실험과 레포트 작성이 수월하며, 성적도 잘 나오는 편입니다. 족보가 필요하고, 기말 프로젝트와 레포트 제출이 중요하지만, 전반적으로 수업 참여와 과제를 충실히 수행하면 좋...
# | time | lectureID: 611, elapsed time: 1.62 seconds |
# |      |
# | info | in 전기기계1 - 612
# 전기기계1 강의는 교수님의 강의력이 좋지만, 내용이 매우 어렵고 시험도 까다롭다는 평가가 많습니다. 족보를 활용해야 좋은 성적을 받을 수 있으며, 예습과 복습이 필수적입니다. 성적은 깐깐하게 주어지므로 많은 노력이 필요합니다.| good | 612	 전기기계1 	 | 전기기계1 강의는 교수님의 강의력이 좋지만, 내용이 매우 어렵고 시험도 까다롭다는 평가가 많습니다. 족보를 활용해야 좋은 성적을 받을 수 있으며, 예습과 복습이 필수적입니다. 성적은 깐깐하게 주어지므로 많은 노력이 필요합니다.
# | time | lectureID: 612, elapsed time: 1.70 seconds |
# |      |
# | info | in 전자회로응용 - 613
# 전자회로응용 강의는 교수님의 강의력이 뛰어나고, 과제와 강의 내용을 충실히 학습하면 좋은 성적을 받을 수 있는 과목입니다. 시험은 다소 어렵고, 개념 이해와 문제 풀이가 중요하며, 강의 자료와 예제를 충분히 활용해야 합니다. 전기과 학생들에게 필수적인 과목으로 추천됩니다.| good | 613	 전자회로응용 	 | 전자회로응용 강의는 교수님의 강의력이 뛰어나고, 과제와 강의 내용을 충실히 학습하면 좋은 성적을 받을 수 있는 과목입니다. 시험은 다소 어렵고, 개념 이해와 문제 풀이가 중요하며, 강의 자료와 예제를 충분히 활용해야 합니다. 전기과 ...
# | time | lectureID: 613, elapsed time: 1.66 seconds |
# |      |
# | info | in 반도체소자공학 - 614
# 반도체소자공학 강의는 난이도가 높고, 교수님의 강의력이 부족하다는 평가가 많습니다. 과제와 예제를 철저히 준비하면 성적을 잘 받을 수 있지만, 교수님의 설명이 지루하고 집중하기 어려운 점이 지적됩니다. 반도체 분야에 관심이 없는 학생에게는 추천되지 않으며, 강의 자료와 시험 준비에 많은 노력이 필요합니다.| good | 614	 반도체소자공학 	 | 반도체소자공학 강의는 난이도가 높고, 교수님의 강의력이 부족하다는 평가가 많습니다. 과제와 예제를 철저히 준비하면 성적을 잘 받을 수 있지만, 교수님의 설명이 지루하고 집중하기 어려운 점이 지적됩니다. 반도체 분야에 관심이 없는 학생...
# | time | lectureID: 614, elapsed time: 1.48 seconds |
# |      |
# | info | in 경력개발과취업전략 - 616
# 경력개발과취업전략 강의는 중간고사 과제로 자기소개서 작성이 있으며, 기말고사는 없습니다. 초반에는 대면 강의로 취업 관련 강사들의 강의를 듣고, 중간 이후에는 비대면으로 졸업생들의 진로 소개 영상을 시청합니다. 부담 없이 학점을 채울 수 있는 과목으로 추천됩니다.| good | 616	 경력개발과취업전략 	 | 경력개발과취업전략 강의는 중간고사 과제로 자기소개서 작성이 있으며, 기말고사는 없습니다. 초반에는 대면 강의로 취업 관련 강사들의 강의를 듣고, 중간 이후에는 비대면으로 졸업생들의 진로 소개 영상을 시청합니다. 부담 없이 학점을 채울...
# | time | lectureID: 616, elapsed time: 1.31 seconds |
# |      |
# | info | in 센서공학 - 617
# 센서공학 강의는 교수님의 친절한 설명과 전반적인 센서 지식 습득이 가능하다는 긍정적인 평가가 많습니다. 과제는 매주 있으며, 시험은 서술형으로 진행되지만 과제를 잘 수행하면 좋은 성적을 받을 수 있습니다. 절대평가로 진행되어 부담이 적고, 센서의 동작 원리에 대한 이해를 높일 수 있는 기회로 여겨집니다.| good | 617	 센서공학 	 | 센서공학 강의는 교수님의 친절한 설명과 전반적인 센서 지식 습득이 가능하다는 긍정적인 평가가 많습니다. 과제는 매주 있으며, 시험은 서술형으로 진행되지만 과제를 잘 수행하면 좋은 성적을 받을 수 있습니다. 절대평가로 진행되어 부담이 ...
# | time | lectureID: 617, elapsed time: 1.40 seconds |
# |      |
# ...
# | time | lectureID: 4342, elapsed time: 1.97 seconds |
# |      |
# | info | in 마케팅조사 - 4343
# 마케팅조사 강의는 마케팅보다는 통계 개념에 중점을 두고 있으며, 교수님의 안내가 부족하다는 평가가 많습니다. 퀴즈와 성적 평가가 엄격하고, 실습 내용이 실질적이지 않다는 의견이 있습니다. 성적을 잘 받으려면 교수님이 강조한 부분을 외우는 것이 중요합니다.| good | 4343	 마케팅조사 	 | 마케팅조사 강의는 마케팅보다는 통계 개념에 중점을 두고 있으며, 교수님의 안내가 부족하다는 평가가 많습니다. 퀴즈와 성적 평가가 엄격하고, 실습 내용이 실질적이지 않다는 의견이 있습니다. 성적을 잘 받으려면 교수님이 강조한 부분을 외...
# | time | lectureID: 4343, elapsed time: 2.02 seconds |
# |      |
# | info | in 기업재무론 - 4344
# 한재현 교수님의 기업재무론 강의는 내용이 어렵지만, 교수님의 열정적인 강의 스타일과 기출문제 제공 덕분에 시험 준비가 수월하다는 평가가 많습니다. 팀 프로젝트와 과제가 있지만, 교수님이 학생들을 잘 도와주고 성적도 후하게 주는 편입니다. 전반적으로 도전적이지만 보람 있는 수업으로, 재무에 흥미가 있는 학생에게 추천됩니다.| good | 4344	 기업재무론 	 | 한재현 교수님의 기업재무론 강의는 내용이 어렵지만, 교수님의 열정적인 강의 스타일과 기출문제 제공 덕분에 시험 준비가 수월하다는 평가가 많습니다. 팀 프로젝트와 과제가 있지만, 교수님이 학생들을 잘 도와주고 성적도 후하게 주는 편입니...
# | time | lectureID: 4344, elapsed time: 2.07 seconds |
# |      |
# | info | in 디지털마케팅 - 4345
# 디지털마케팅 강의는 흥미로운 내용으로 연강이 수월하며, 발표와 참여 점수가 중요합니다. 개인과제와 팀플 과제가 있으며, 중간고사는 없고 발표 부담은 크지 않은 편입니다. 적극적인 참여가 요구됩니다.| good | 4345	 디지털마케팅 	 | 디지털마케팅 강의는 흥미로운 내용으로 연강이 수월하며, 발표와 참여 점수가 중요합니다. 개인과제와 팀플 과제가 있으며, 중간고사는 없고 발표 부담은 크지 않은 편입니다. 적극적인 참여가 요구됩니다.
# | time | lectureID: 4345, elapsed time: 1.59 seconds |
# |      |
# | info | in 비즈니스와사회적공헌 - 4346
# 비즈니스와 사회적 공헌 강의는 난이도가 낮고 수업 부담이 적으며, 독후감 제출로 평가되는 점이 특징입니다. 수업 내용은 흥미로울 수 있으나, 교수님의 강의력에 대한 부정적인 평가와 채점 기준의 불명확함이 지적되고 있습니다. 전반적으로 쉬어가는 수업으로 추천되지만, 유익함은 개인의 노력에 따라 달라질 수 있습니다.| good | 4346	 비즈니스와사회적공헌 	 | 비즈니스와 사회적 공헌 강의는 난이도가 낮고 수업 부담이 적으며, 독후감 제출로 평가되는 점이 특징입니다. 수업 내용은 흥미로울 수 있으나, 교수님의 강의력에 대한 부정적인 평가와 채점 기준의 불명확함이 지적되고 있습니다. 전반적으로...
# | time | lectureID: 4346, elapsed time: 2.51 seconds |
# |      |
# | info | in 데이터사이언스개론 - 4347
# 최재운 교수님의 데이터사이언스개론 강의는 친절하고 세세한 강의자료로 학생들이 공부하기 편리하며, 실습도 포함되어 있어 흥미롭습니다. 교수님의 배려와 열정적인 수업 진행이 긍정적으로 평가되고 있습니다. 다만, 후반부 내용이 다소 어려울 수 있습니다.| good | 4347	 데이터사이언스개론 	 | 최재운 교수님의 데이터사이언스개론 강의는 친절하고 세세한 강의자료로 학생들이 공부하기 편리하며, 실습도 포함되어 있어 흥미롭습니다. 교수님의 배려와 열정적인 수업 진행이 긍정적으로 평가되고 있습니다. 다만, 후반부 내용이 다소 어려울...
# | time | lectureID: 4347, elapsed time: 1.59 seconds |
# |      |
# | info | in 국제경영 - 4348
# 국제경영 강의는 교수님이 학생 의견을 적극 반영하고 친절하게 수업을 진행하여 유익하다는 평가를 받습니다. 시험 준비를 위한 요약 제공과 개인 프로젝트 발표가 있으며, 자료 조사와 이론 적용이 중요합니다. 다만, 성적이 예상보다 낮을 수 있으니 주의가 필요합니다.| good | 4348	 국제경영 	 | 국제경영 강의는 교수님이 학생 의견을 적극 반영하고 친절하게 수업을 진행하여 유익하다는 평가를 받습니다. 시험 준비를 위한 요약 제공과 개인 프로젝트 발표가 있으며, 자료 조사와 이론 적용이 중요합니다. 다만, 성적이 예상보다 낮을 ...
# | time | lectureID: 4348, elapsed time: 1.56 seconds |
# |      |
# | info | in 세무회계 - 4349
# 세무회계 강의는 내용이 어려운 편이지만, 교수님이 친절하고 열정적으로 학생들을 챙겨주며, 퀴즈와 문제풀이를 통해 시험 준비가 가능하다는 평가가 많습니다. 학생들이 열심히 복습하면 좋은 성적을 받을 수 있지만, 회계 관련 배경이 없는 경우 어려움을 겪을 수 있습니다.| good | 4349	 세무회계 	 | 세무회계 강의는 내용이 어려운 편이지만, 교수님이 친절하고 열정적으로 학생들을 챙겨주며, 퀴즈와 문제풀이를 통해 시험 준비가 가능하다는 평가가 많습니다. 학생들이 열심히 복습하면 좋은 성적을 받을 수 있지만, 회계 관련 배경이 없는 ...
# | time | lectureID: 4349, elapsed time: 1.91 seconds |
# |      |
# | pass | 4350 | len(reviews) < 3
# | info | in 실용금융 - 4351
# 실용금융 강의는 비대면으로 진행되며, 실생활에 유용한 금융 지식을 배울 수 있는 수업입니다. 시험은 쉽게 출제되지만, 기출 문제와 자료를 활용해 미리 준비해야 합니다. 고학년에게 학점 채우기 용도로 추천됩니다.| good | 4351	 실용금융 	 | 실용금융 강의는 비대면으로 진행되며, 실생활에 유용한 금융 지식을 배울 수 있는 수업입니다. 시험은 쉽게 출제되지만, 기출 문제와 자료를 활용해 미리 준비해야 합니다. 고학년에게 학점 채우기 용도로 추천됩니다.
# | time | lectureID: 4351, elapsed time: 1.31 seconds |
# |      |
# | info | in 브랜드관리 - 4352
# 브랜드관리 강의는 교수님의 열정과 실무 중심의 사례 중심 수업으로 재미있다는 평가가 많습니다. 그러나 시험은 양이 많고 어려워 철저한 준비가 필요하며, 조별과제와 개인과제가 있어 부담이 될 수 있습니다. 전반적으로 흥미롭고 유익한 수업이지만, 학점에 대한 부담이 클 수 있습니다.| good | 4352	 브랜드관리 	 | 브랜드관리 강의는 교수님의 열정과 실무 중심의 사례 중심 수업으로 재미있다는 평가가 많습니다. 그러나 시험은 양이 많고 어려워 철저한 준비가 필요하며, 조별과제와 개인과제가 있어 부담이 될 수 있습니다. 전반적으로 흥미롭고 유익한 수...
# | time | lectureID: 4352, elapsed time: 1.87 seconds |
# |      |
# | info | in 금융과인공지능 - 4353
# 금융과인공지능 강의는 파이썬 실력이 필수이며, 과제가 모두 파이썬으로 진행됩니다. 절대평가일 때 수강할 수 있으며, 난이도가 높아 문과 학생에게는 어려울 수 있습니다. 교수님은 좋지만, 파이썬에 자신이 없는 학생은 듣지 않는 것이 좋습니다.| good | 4353	 금융과인공지능 	 | 금융과인공지능 강의는 파이썬 실력이 필수이며, 과제가 모두 파이썬으로 진행됩니다. 절대평가일 때 수강할 수 있으며, 난이도가 높아 문과 학생에게는 어려울 수 있습니다. 교수님은 좋지만, 파이썬에 자신이 없는 학생은 듣지 않는 것이 좋...
# | time | lectureID: 4353, elapsed time: 1.58 seconds |
# |      |
# | info | in 성공적인창업계획 - 4354
# 성공적인창업계획 강의는 절대평가로 진행되며, 교수님이 매우 친절하고 배려가 많아 학생들에게 많은 배움을 제공합니다. 과제와 팀 프로젝트가 많아 난이도가 높지만, 창업에 관심 있는 학생들에게는 유익한 수업으로 추천됩니다. 상대평가일 경우 학점 취득이 어려울 수 있으니 주의가 필요합니다.| good | 4354	 성공적인창업계획 	 | 성공적인창업계획 강의는 절대평가로 진행되며, 교수님이 매우 친절하고 배려가 많아 학생들에게 많은 배움을 제공합니다. 과제와 팀 프로젝트가 많아 난이도가 높지만, 창업에 관심 있는 학생들에게는 유익한 수업으로 추천됩니다. 상대평가일 경...
# | time | lectureID: 4354, elapsed time: 1.82 seconds |
# |      |
# | info | in 벤처경영 - 4355
# 벤처경영 강의는 절대평가로, 발표와 팀 프로젝트가 많지만 교수님이 내용 중심으로 평가해 주어 부담이 적습니다. 교수님의 인사이트와 유머가 유익하나, 피드백은 하드코어한 편입니다. 수업에 집중하고 팀원과 좋은 주제를 선정하면 좋은 결과를 얻을 수 있습니다.| good | 4355	 벤처경영 	 | 벤처경영 강의는 절대평가로, 발표와 팀 프로젝트가 많지만 교수님이 내용 중심으로 평가해 주어 부담이 적습니다. 교수님의 인사이트와 유머가 유익하나, 피드백은 하드코어한 편입니다. 수업에 집중하고 팀원과 좋은 주제를 선정하면 좋은 결과...
# | time | lectureID: 4355, elapsed time: 1.66 seconds |
# |      |
# | pass | 4358 | len(reviews) < 3
# | info | in 경제경영통계 - 4359
# 경제경영통계 강의는 교수님의 설명이 친절하고 상세하지만, 수업 내용이 어려워 열심히 공부해야 합니다. 팀플과 출석이 성적에 큰 영향을 미치며, 조별 과제가 많아 부담이 될 수 있습니다. 전필이 아니라면 수강을 피하는 것이 좋고, 성적이 낮은 학생들이 많아 주의가 필요합니다.| good | 4359	 경제경영통계 	 | 경제경영통계 강의는 교수님의 설명이 친절하고 상세하지만, 수업 내용이 어려워 열심히 공부해야 합니다. 팀플과 출석이 성적에 큰 영향을 미치며, 조별 과제가 많아 부담이 될 수 있습니다. 전필이 아니라면 수강을 피하는 것이 좋고, 성적...
# | time | lectureID: 4359, elapsed time: 3.91 seconds |
# |      |
# | info | in 일본어기초2 - 4360
# 일본어기초2 강의는 교수님의 친절한 설명과 배려로 학생들의 일본어 실력 향상에 큰 도움이 되며, 매주 과제와 발표가 있지만 부담스럽지 않고 오히려 학습에 긍정적인 영향을 미친다는 평가가 많습니다. 시험은 어렵지만 교수님이 포인트를 잘 짚어주어 성적을 잘 받을 수 있는 기회가 많습니다. 초심자도 수업을 따라가기 쉬운 구조로 되어 있어 추천할 만한 강의입니다.| good | 4360	 일본어기초2 	 | 일본어기초2 강의는 교수님의 친절한 설명과 배려로 학생들의 일본어 실력 향상에 큰 도움이 되며, 매주 과제와 발표가 있지만 부담스럽지 않고 오히려 학습에 긍정적인 영향을 미친다는 평가가 많습니다. 시험은 어렵지만 교수님이 포인트를 잘...
# | time | lectureID: 4360, elapsed time: 4.42 seconds |
# |      |
# | pass | 4361 | len(reviews) < 3
# | info | in 중국어기초2 - 4362
# 중국어기초2 강의는 교수님의 친절한 설명과 쉬운 시험으로 긍정적인 평가를 받고 있으며, 한자와 문법을 잘 외우면 좋은 성적을 받을 수 있습니다. 팀 프로젝트는 간단하고 과제 압박은 크지 않지만, 본인이 잘 챙겨야 합니다.| good | 4362	 중국어기초2 	 | 중국어기초2 강의는 교수님의 친절한 설명과 쉬운 시험으로 긍정적인 평가를 받고 있으며, 한자와 문법을 잘 외우면 좋은 성적을 받을 수 있습니다. 팀 프로젝트는 간단하고 과제 압박은 크지 않지만, 본인이 잘 챙겨야 합니다.
# | time | lectureID: 4362, elapsed time: 1.56 seconds |
# |      |
# | info | in 거시경제학 - 4364
# 거시경제학 강의는 교수님의 강의력이 뛰어나고, 학점이 후하게 주어지는 편입니다. 팀 프로젝트가 많고 난이도가 있지만, 과정을 중시하며 많은 것을 배울 수 있는 수업입니다. 시험은 기출문제에서 그대로 출제되므로, 열심히 준비하면 좋은 성적을 받을 수 있습니다.| good | 4364	 거시경제학 	 | 거시경제학 강의는 교수님의 강의력이 뛰어나고, 학점이 후하게 주어지는 편입니다. 팀 프로젝트가 많고 난이도가 있지만, 과정을 중시하며 많은 것을 배울 수 있는 수업입니다. 시험은 기출문제에서 그대로 출제되므로, 열심히 준비하면 좋은 ...
# | time | lectureID: 4364, elapsed time: 1.65 seconds |
# |      |
# | info | in 무역영어 - 4366
# 무역영어 강의는 영어 실력이 중요하며, 발표와 퀴즈가 많아 준비가 필요합니다. 기말고사는 방대한 범위에서 출제되지만, 열심히 준비하면 좋은 성적을 받을 수 있습니다. 전반적으로 수업이 빡세지만 유익하다는 평가가 많습니다.| good | 4366	 무역영어 	 | 무역영어 강의는 영어 실력이 중요하며, 발표와 퀴즈가 많아 준비가 필요합니다. 기말고사는 방대한 범위에서 출제되지만, 열심히 준비하면 좋은 성적을 받을 수 있습니다. 전반적으로 수업이 빡세지만 유익하다는 평가가 많습니다.
# | time | lectureID: 4366, elapsed time: 1.54 seconds |
# |      |
# | info | in 미시경제학 - 4367
# 미시경제학 강의는 난이도가 높고 과제가 많아 학생들이 많은 노력을 요구합니다. 교수님은 열정적이지만 설명이 불친절하고, TA 세션에 참석하지 않으면 독학이 어려운 구조입니다. 성적은 본인의 공부량에 따라 결정되며, 경제학에 관심이 있는 학생에게 추천됩니다.| good | 4367	 미시경제학 	 | 미시경제학 강의는 난이도가 높고 과제가 많아 학생들이 많은 노력을 요구합니다. 교수님은 열정적이지만 설명이 불친절하고, TA 세션에 참석하지 않으면 독학이 어려운 구조입니다. 성적은 본인의 공부량에 따라 결정되며, 경제학에 관심이 있...
# | time | lectureID: 4367, elapsed time: 1.86 seconds |
# |      |
# | pass | 4369 | len(reviews) < 3
# | info | in 글로벌경영 - 4371
# 글로벌경영 강의는 교수님의 실무 경험과 흥미로운 강의 내용으로 많은 학생들에게 긍정적인 평가를 받고 있습니다. 수업은 재미있지만, 학점 취득이 쉽지 않으며 시험 준비에 꼼꼼한 공부가 필요합니다. 교수님은 학생들에게 많은 정보를 제공하고, 수업에 대한 애정이 느껴지는 강의입니다.| good | 4371	 글로벌경영 	 | 글로벌경영 강의는 교수님의 실무 경험과 흥미로운 강의 내용으로 많은 학생들에게 긍정적인 평가를 받고 있습니다. 수업은 재미있지만, 학점 취득이 쉽지 않으며 시험 준비에 꼼꼼한 공부가 필요합니다. 교수님은 학생들에게 많은 정보를 제공하...
# | time | lectureID: 4371, elapsed time: 3.93 seconds |
# |      |
# | info | in 글로벌경영 - 4372
# 글로벌경영 강의는 교수님의 실무 경험과 흥미로운 강의 내용으로 많은 학생들이 긍정적으로 평가하고 있으며, 수업은 재미있지만 학점 받기가 쉽지 않다는 의견이 많습니다. 시험은 내용이 쉬운 편이지만, 꼼꼼한 준비가 필요하고 서술형 문제도 출제됩니다. 전반적으로 많은 것을 배울 수 있는 유익한 수업입니다.| good | 4372	 글로벌경영 	 | 글로벌경영 강의는 교수님의 실무 경험과 흥미로운 강의 내용으로 많은 학생들이 긍정적으로 평가하고 있으며, 수업은 재미있지만 학점 받기가 쉽지 않다는 의견이 많습니다. 시험은 내용이 쉬운 편이지만, 꼼꼼한 준비가 필요하고 서술형 문제도...
# | time | lectureID: 4372, elapsed time: 1.93 seconds |
# |      |
# | info | in 국제회의영어 - 4373
# 국제회의영어 강의는 매주 간단한 과제가 있으며, 팀 활동과 롤플레잉이 포함되어 있습니다. 교수님은 친절하고 학생들에게 배려가 많지만, 수업 내용은 반복적이고 영어 실력 향상에는 큰 도움이 되지 않는다는 평가가 있습니다. 시험은 기말에 한 번 있으며, 과제와 수업 내용을 잘 준비하면 학점은 쉽게 받을 수 있습니다.| good | 4373	 국제회의영어 	 | 국제회의영어 강의는 매주 간단한 과제가 있으며, 팀 활동과 롤플레잉이 포함되어 있습니다. 교수님은 친절하고 학생들에게 배려가 많지만, 수업 내용은 반복적이고 영어 실력 향상에는 큰 도움이 되지 않는다는 평가가 있습니다. 시험은 기말에...
# | time | lectureID: 4373, elapsed time: 1.87 seconds |
# |      |
# | info | in 국제회의영어 - 4374
# 국제회의영어 강의는 영어 실력이 좋은 학생에게 유리하며, 조별 활동과 과제가 많아 영어 실력 향상에 도움이 될 수 있지만, 영어에 자신이 없는 학생에게는 어려울 수 있습니다. 중간고사는 필기, 기말고사는 1:1 면접으로 진행되며, 수업 내용이 시험에 직접적으로 반영되지 않는 경향이 있습니다. 전반적으로 무난한 강의로 평가됩니다.| good | 4374	 국제회의영어 	 | 국제회의영어 강의는 영어 실력이 좋은 학생에게 유리하며, 조별 활동과 과제가 많아 영어 실력 향상에 도움이 될 수 있지만, 영어에 자신이 없는 학생에게는 어려울 수 있습니다. 중간고사는 필기, 기말고사는 1:1 면접으로 진행되며, 수...
# | time | lectureID: 4374, elapsed time: 4.06 seconds |
# |      |
# | info | in 중국어비즈니스작문 - 4375
# 중국어비즈니스작문 강의는 교수님의 친절한 지도와 쉬운 시험으로 긍정적인 평가를 받고 있으며, 개인 발음 교정과 작문 첨삭이 제공되어 학습에 도움이 됩니다. 팀 발표는 부담이 적고, 문화 관련 내용도 포함되어 있어 유익한 수업입니다.| good | 4375	 중국어비즈니스작문 	 | 중국어비즈니스작문 강의는 교수님의 친절한 지도와 쉬운 시험으로 긍정적인 평가를 받고 있으며, 개인 발음 교정과 작문 첨삭이 제공되어 학습에 도움이 됩니다. 팀 발표는 부담이 적고, 문화 관련 내용도 포함되어 있어 유익한 수업입니다.
# | time | lectureID: 4375, elapsed time: 1.72 seconds |
# |      |
# | info | in 중국어비즈니스작문 - 4376
# 중국어비즈니스작문 강의는 교수님이 친절하고 학생 편의를 잘 봐주지만, 매주 단어시험과 방대한 시험 범위, 원고지 작성 과제가 부담스럽다는 의견이 많습니다. 성적은 절대평가로 잘 주지만, 과제와 발표 준비가 필요하며, 수업 방식이 맞지 않는 학생도 있는 것으로 보입니다.| good | 4376	 중국어비즈니스작문 	 | 중국어비즈니스작문 강의는 교수님이 친절하고 학생 편의를 잘 봐주지만, 매주 단어시험과 방대한 시험 범위, 원고지 작성 과제가 부담스럽다는 의견이 많습니다. 성적은 절대평가로 잘 주지만, 과제와 발표 준비가 필요하며, 수업 방식이 맞지...
# | time | lectureID: 4376, elapsed time: 2.11 seconds |
# |      |
# | info | in 무역상무연습 - 4378
# 무역상무연습 강의는 홍의 교수님의 뛰어난 강의력과 체계적인 수업 방식으로 많은 학생들에게 추천받고 있습니다. 과제와 시험 준비가 다소 어렵고 양이 많지만, 무역 관련 진로에 관심이 있는 학생들에게는 유익한 강의로 평가됩니다. 팀 프로젝트와 발표가 포함되어 있으며, 교수님과의 소통이 원활하다는 점도 긍정적으로 언급되고 있습니다.| good | 4378	 무역상무연습 	 | 무역상무연습 강의는 홍의 교수님의 뛰어난 강의력과 체계적인 수업 방식으로 많은 학생들에게 추천받고 있습니다. 과제와 시험 준비가 다소 어렵고 양이 많지만, 무역 관련 진로에 관심이 있는 학생들에게는 유익한 강의로 평가됩니다. 팀 프로...
# | time | lectureID: 4378, elapsed time: 2.71 seconds |
# |      |
# | info | in 시사일본어연습 - 4379
# 시사일본어연습 강의는 일본어 실력이 부족한 학생에게는 매우 어려운 수업으로, 일본 경제 관련 기사를 해석하는 통번역 시험이 포함되어 있습니다. 수업 내용은 주로 신문 기사를 읽는 방식이며, 일본어를 잘하는 학생에게는 얻어가는 것이 적고, 노력한 만큼 성적이 나오는 경향이 있습니다. 전반적으로 일본어 실력이 중급 이상인 학생에게 적합한 강의입니다.| good | 4379	 시사일본어연습 	 | 시사일본어연습 강의는 일본어 실력이 부족한 학생에게는 매우 어려운 수업으로, 일본 경제 관련 기사를 해석하는 통번역 시험이 포함되어 있습니다. 수업 내용은 주로 신문 기사를 읽는 방식이며, 일본어를 잘하는 학생에게는 얻어가는 것이 적...
# | time | lectureID: 4379, elapsed time: 1.73 seconds |
# |      |
# | pass | 4380 | len(reviews) < 3
# | pass | 4381 | len(reviews) < 3
# | info | in 국제통상규범론 - 4382
# 주윤 교수님의 국제통상규범론 강의는 강의력이 뛰어나고 수업이 재미있지만, 시험이 헷갈리게 출제되므로 꼼꼼한 공부가 필요합니다. 발표를 통해 가산점을 받을 수 있으며, 성적은 기말에서 갈리는 경향이 있습니다. 꾸준히 준비하면 A+도 가능하다고 합니다.| good | 4382	 국제통상규범론 	 | 주윤 교수님의 국제통상규범론 강의는 강의력이 뛰어나고 수업이 재미있지만, 시험이 헷갈리게 출제되므로 꼼꼼한 공부가 필요합니다. 발표를 통해 가산점을 받을 수 있으며, 성적은 기말에서 갈리는 경향이 있습니다. 꾸준히 준비하면 A+도 가...
# | time | lectureID: 4382, elapsed time: 1.64 seconds |
# |      |
# | pass | 4383 | len(reviews) < 3
# | info | in 경력개발과취업전략 - 4387
# 경력개발과취업전략 강의는 다양한 산업에서 활동 중인 선배들과 외부 강사의 취업 관련 정보를 제공받을 수 있는 유익한 기회입니다. 3학년이나 4학년 때 수강하면 더욱 도움이 될 것으로 보입니다.| good | 4387	 경력개발과취업전략 	 | 경력개발과취업전략 강의는 다양한 산업에서 활동 중인 선배들과 외부 강사의 취업 관련 정보를 제공받을 수 있는 유익한 기회입니다. 3학년이나 4학년 때 수강하면 더욱 도움이 될 것으로 보입니다.
# | time | lectureID: 4387, elapsed time: 2.04 seconds |
# |      |
# | info | in 국제운송론 - 4388
# 국제운송론 강의는 팀 프로젝트나 과제가 없어 학기 중에는 편하지만, 시험 범위가 매우 넓고 난이도가 높아 학점이 잘 나오지 않는다는 평가가 많습니다. 수업 내용은 국제운송과 무역에 대한 전반적인 내용으로, 흥미가 있는 학생에게만 추천됩니다.| good | 4388	 국제운송론 	 | 국제운송론 강의는 팀 프로젝트나 과제가 없어 학기 중에는 편하지만, 시험 범위가 매우 넓고 난이도가 높아 학점이 잘 나오지 않는다는 평가가 많습니다. 수업 내용은 국제운송과 무역에 대한 전반적인 내용으로, 흥미가 있는 학생에게만 추천...
# | time | lectureID: 4388, elapsed time: 1.50 seconds |
# |      |
# | pass | 4391 | len(reviews) < 3
# | pass | 4392 | len(reviews) < 3
# | pass | 4393 | len(reviews) < 3
# | info | in 초급중국어1 - 4394
# 초급중국어1 강의는 교수님이 매우 친절하고 학생들의 의견을 존중하며, 절대평가로 부담 없이 수업을 진행합니다. 강의 내용은 쉽게 이해할 수 있도록 구성되어 있으며, 과제와 시험이 간단해 학점 취득이 용이합니다. 초보자도 쉽게 배울 수 있는 강의로 추천됩니다.| good | 4394	 초급중국어1 	 | 초급중국어1 강의는 교수님이 매우 친절하고 학생들의 의견을 존중하며, 절대평가로 부담 없이 수업을 진행합니다. 강의 내용은 쉽게 이해할 수 있도록 구성되어 있으며, 과제와 시험이 간단해 학점 취득이 용이합니다. 초보자도 쉽게 배울 수...
# | time | lectureID: 4394, elapsed time: 1.74 seconds |
# |      |
# | pass | 4395 | len(reviews) < 3
# | info | in 한국영화사로보는가족 - 4398
# 강의는 한국 영화와 가부장제를 주제로 하며, 출석과 과제가 중요합니다. 시험은 서술형으로, 교수님의 강의력과 평가 기준이 불공정하다는 비판이 많습니다. 영화에 대한 흥미가 있다면 수업이 재미있을 수 있으나, 교수의 편향된 태도와 까다로운 성적 기준으로 인해 추천하지 않는 의견이 많습니다.| good | 4398	 한국영화사로보는가족 	 | 강의는 한국 영화와 가부장제를 주제로 하며, 출석과 과제가 중요합니다. 시험은 서술형으로, 교수님의 강의력과 평가 기준이 불공정하다는 비판이 많습니다. 영화에 대한 흥미가 있다면 수업이 재미있을 수 있으나, 교수의 편향된 태도와 까다...
# | time | lectureID: 4398, elapsed time: 1.94 seconds |
# |      |
# | info | in 디지털신기술기반신재생에너지 - 4399
# 디지털신기술기반신재생에너지 강의는 온라인으로 진행되며, 시험과 퀴즈가 족보에 의존하는 경향이 강해 족보를 활용하면 좋은 성적을 받을 수 있습니다. 그러나 공지사항이 불명확하고 성적 처리가 늦어 불만이 많으며, 강의 내용이 방대하고 어려운 편입니다. 관심이 있는 학생에게는 유익할 수 있지만, 전공 지식이 부족한 학생에게는 힘들 수 있습니다.| good | 4399	 디지털신기술기반신재생에너지 	 | 디지털신기술기반신재생에너지 강의는 온라인으로 진행되며, 시험과 퀴즈가 족보에 의존하는 경향이 강해 족보를 활용하면 좋은 성적을 받을 수 있습니다. 그러나 공지사항이 불명확하고 성적 처리가 늦어 불만이 많으며, 강의 내용이 방대하고 어...
# | time | lectureID: 4399, elapsed time: 2.16 seconds |
# |      |
# | info | in 슬기로운가정생활,관계놀이 - 4400
# 슬기로운가정생활, 관계놀이 강의는 난이도가 낮고, 온라인 강의로 수업 부담이 적습니다. 중간시험과 기말 과제가 있으며, 성적은 상대평가로 쉽게 A를 받을 수 있지만, 과제를 충실히 수행해야 합니다. 전반적으로 수업 내용이 쉽고, 퀴즈와 과제로 출석 체크가 이루어져 편리하다는 평가가 많습니다.| good | 4400	 슬기로운가정생활,관계놀이 	 | 슬기로운가정생활, 관계놀이 강의는 난이도가 낮고, 온라인 강의로 수업 부담이 적습니다. 중간시험과 기말 과제가 있으며, 성적은 상대평가로 쉽게 A를 받을 수 있지만, 과제를 충실히 수행해야 합니다. 전반적으로 수업 내용이 쉽고, 퀴즈...
# | time | lectureID: 4400, elapsed time: 1.79 seconds |
# |      |
# | info | in 슬기로운가정생활,관계놀이 - 4401
# 슬기로운가정생활, 관계놀이 강의는 난이도가 낮고, 과제와 시험이 비교적 쉬워 성적을 잘 받을 수 있는 과목입니다. 중간고사는 주관식 시험과 온라인/오프라인 과제로 진행되며, 기말은 대체 과제로 관계놀이 영상과 보고서 작성이 포함됩니다. 전반적으로 수업 내용이 쉽고, 출석 체크가 간단해 부담이 적습니다.| good | 4401	 슬기로운가정생활,관계놀이 	 | 슬기로운가정생활, 관계놀이 강의는 난이도가 낮고, 과제와 시험이 비교적 쉬워 성적을 잘 받을 수 있는 과목입니다. 중간고사는 주관식 시험과 온라인/오프라인 과제로 진행되며, 기말은 대체 과제로 관계놀이 영상과 보고서 작성이 포함됩니다...
# | time | lectureID: 4401, elapsed time: 2.18 seconds |
# |      |
# | info | in ICT가바꾸는미래의법 - 4402
# ICT가바꾸는미래의법 강의는 내용이 방대하고 과제 및 시험이 많아 공부량이 상당히 많습니다. 시험은 객관식으로 출제되지만, 준비가 부족하면 어려울 수 있으며, 최신 자료 반영이 부족하다는 아쉬움이 있습니다. 관심 있는 주제라면 흥미롭게 들을 수 있지만, 전공 수준의 공부가 필요합니다.| good | 4402	 ICT가바꾸는미래의법 	 | ICT가바꾸는미래의법 강의는 내용이 방대하고 과제 및 시험이 많아 공부량이 상당히 많습니다. 시험은 객관식으로 출제되지만, 준비가 부족하면 어려울 수 있으며, 최신 자료 반영이 부족하다는 아쉬움이 있습니다. 관심 있는 주제라면 흥미롭...
# | time | lectureID: 4402, elapsed time: 2.08 seconds |
# |      |
# | info | in 현대중국예술과문화코드이해 - 4403
# 현대중국예술과문화코드이해 강의는 강의량이 많고 외울 내용이 많아 부담이 크지만, 흥미로운 주제를 다루고 있습니다. 중간과 기말에 각각 과제가 있으며, 온라인과 오프라인 시험을 모두 치러야 합니다. 성실히 공부하면 좋은 성적을 받을 수 있지만, 공지사항과 강의자료에 대한 혼란이 있을 수 있습니다.| good | 4403	 현대중국예술과문화코드이해 	 | 현대중국예술과문화코드이해 강의는 강의량이 많고 외울 내용이 많아 부담이 크지만, 흥미로운 주제를 다루고 있습니다. 중간과 기말에 각각 과제가 있으며, 온라인과 오프라인 시험을 모두 치러야 합니다. 성실히 공부하면 좋은 성적을 받을 수...
# | time | lectureID: 4403, elapsed time: 2.72 seconds |
# |      |
# | info | in 배터리신기술과우리의생활 - 4404
# 배터리신기술과우리의생활 강의는 비대면으로 진행되며, 전범위 서술형 시험과 매주 퀴즈가 있어 학습 부담이 크지만, 관련 전공자에게는 유익할 수 있습니다. 강의 내용이 교양 수준을 넘어선다는 평가가 많고, 성적을 잘 받기 위해서는 굵직한 내용 위주로 공부해야 합니다. 관심이 없다면 추천하지 않습니다.| good | 4404	 배터리신기술과우리의생활 	 | 배터리신기술과우리의생활 강의는 비대면으로 진행되며, 전범위 서술형 시험과 매주 퀴즈가 있어 학습 부담이 크지만, 관련 전공자에게는 유익할 수 있습니다. 강의 내용이 교양 수준을 넘어선다는 평가가 많고, 성적을 잘 받기 위해서는 굵직한...
# | time | lectureID: 4404, elapsed time: 2.02 seconds |
# |      |
# | info | in 수학적사고로보는세상 - 4405
# 수학적사고로보는세상 강의는 상대평가로 과제가 쉬운 편이며, 온라인 강의로 수업이 진행됩니다. 수학적 지식이 아닌 사고 방식을 중점적으로 다루지만, 교수님과의 커뮤니케이션이 부족하고 공지사항이 불명확하다는 지적이 있습니다. 전반적으로 성적은 잘 주지만, 교수님과의 스타일이 맞지 않으면 어려움을 겪을 수 있습니다.| good | 4405	 수학적사고로보는세상 	 | 수학적사고로보는세상 강의는 상대평가로 과제가 쉬운 편이며, 온라인 강의로 수업이 진행됩니다. 수학적 지식이 아닌 사고 방식을 중점적으로 다루지만, 교수님과의 커뮤니케이션이 부족하고 공지사항이 불명확하다는 지적이 있습니다. 전반적으로 ...
# | time | lectureID: 4405, elapsed time: 1.88 seconds |
# |      |
# | pass | 4406 | len(reviews) < 3
# | pass | 4407 | len(reviews) < 3
